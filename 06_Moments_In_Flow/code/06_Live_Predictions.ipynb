# %%
from tensorflow.keras.models import load_model
import numpy as np
import os
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %matplotlib inline

# %%
poses = os.listdir('../images/incoming_images/')
poses
# Out:
# ['.DS_Store',
#  'warrior_iii',
#  'warrior_ii',
#  'crow',
#  'downward_facing_dog',
#  'supported_shoulder_stand']

# %%
# https://kite.com/python/examples/4887/pil-convert-between-a-pil-%60image%60-and-a-numpy-%60array%60

def predict_image(image, model):
    image = np.array(image, dtype='float32')
    image = image/255
    pred_array = model.predict(image)

    # model.predict() returns an array of probabilities - 
    # np.argmax grabs the index of the highest probability.
#     result = gesture_names[]
    result = poses[np.argmax(pred_array)]
    # A bit of magic here - the score is a float, but I wanted to
    # display just 2 digits beyond the decimal point.
    score = float("%0.2f" % (max(pred_array[0]) * 100))
    print(f'Result: {result}, Score: {score}')
    return result, score

# %%
# https://stackoverflow.com/questions/26649716/how-to-show-pil-image-in-ipython-notebook
def get_predictions(img_path,model):
    im = Image.open(img_path)

    im_resize = im.resize((244,244))
    np_im = np.array(im_resize)
    np_im_reshape = np_im.reshape((1,244,244,3))

    result, score = predict_image(np_im_reshape,model)
    pil_im = Image.open(img_path)
    plt.imshow(np.asarray(pil_im))
#     im.show(title=f"{result} {score}")

    plt.show();

# %%
root, dirs, files = next(os.walk('../images/testing_images/'))
# '../images/testing_images/Photo on 12-3-19 at 4.02 PM.jpg'

img_paths = [os.path.join(root,file) for file in files[1:]]

# %%
model_path = '../models/resnet_10_epochs.h5'

model = load_model(model_path) # open saved model/weights from .h5 file
# Out:
# WARNING:tensorflow:From /anaconda3/envs/deep-learning/lib/python3.7/site-packages/tensorflow_core/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /anaconda3/envs/deep-learning/lib/python3.7/site-packages/tensorflow_core/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# ...

# %%
model.

# %%
model_path = '../models/resnet_10_epochs.h5'

model = load_model(model_path) # open saved model/weights from .h5 file

for img_path in img_paths:
    get_predictions(img_path,model)
# Out:
# WARNING:tensorflow:From /anaconda3/envs/deep-learning/lib/python3.7/site-packages/tensorflow_core/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /anaconda3/envs/deep-learning/lib/python3.7/site-packages/tensorflow_core/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# ...

# %%
model_path = '../models/cnn_5_classes_50_epoch_augmented.h5'

model = load_model(model_path) # open saved model/weights from .h5 file

for img_path in img_paths:
    get_predictions(img_path,model)

# %%
model_path = '../models/cnn_5_classes_10_epoch_augmented_v2a.h5'

model = load_model(model_path) # open saved model/weights from .h5 file

for img_path in img_paths:
    get_predictions(img_path,model)

# %%
model_path = '../models/cnn_5_classes_10_epoch_augmented_v3.h5'

model = load_model(model_path) # open saved model/weights from .h5 file

for img_path in img_paths:
    get_predictions(img_path,model)

# %%
model_path = '../models/cnn_5_classes_10_epoch_augmented_v4.h5'

model = load_model(model_path) # open saved model/weights from .h5 file

for img_path in img_paths:
    get_predictions(img_path,model)

# %%
model_path = '../models/cnn_2layers_5classes_150epoch_augmentedv1.h5'

model = load_model(model_path) # open saved model/weights from .h5 file

for img_path in img_paths:
    get_predictions(img_path,model)
# Out:
# Result: crescent, Score: 54.74
# Result: crescent, Score: 44.94
# Result: crescent, Score: 50.71
# Result: crescent, Score: 27.18
# Result: crow, Score: 29.49
