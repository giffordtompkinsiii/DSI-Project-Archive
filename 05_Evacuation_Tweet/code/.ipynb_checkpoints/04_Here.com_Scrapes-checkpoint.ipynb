# %% [markdown]
# # Here.com API

# %% [markdown]
# ### OBJECTIVE

# %% [markdown]
# - This notebook requires a valid Here.com API ID and Code. The goal of this notebook is to gather location information relative to road closures in California. Register at: https://developer.here.com to create an account and request API credentials.

# %%
#Import libraries 

import json, requests
import time, datetime
import pandas as pd

# Viewing configs for notebook
# %matplotlib inline
# %config InlineBackend.print_figure_kwargs={'facecolor' : 'w'}
# Code below allows multiple console outputs to be generated without print statements
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
with open('../creds/samples/here-api.json') as cred_data:
    info = json.load(cred_data)
    APP_ID = info['APP_ID']
    APP_CODE = info['APP_CODE']

# %%
#Ideally, we would like someone do be able to pick a location and the bounding box will update 

#bounding box coordinates from San Franciso:
top_left='36.5552182,-78.707858' 
bottom_right='33.8398322919, -75.3641955'

# %%
# Set url to be the here.com API and insert creds
url = f'https://traffic.api.here.com/traffic/6.3/incidents.json?app_id={APP_ID}&app_code={APP_CODE}&bbox={top_left};{bottom_right}&criticality=critical'

# %%
# Request for data from Here.com Maps
res = requests.get(url)
date_requested = time.strftime('%Y-%m-%d')
time_requested = time.strftime('%H:%M') # 24-hour format
date_requested; time_requested
# Out:
# '2019-11-13'
# '14:37'

# %%
# Check to make sure status code is 200
res.status_code
# Out:
# 200

# %%
# Display the json as dictionary
hmaps_json = res.json()
hmaps_json
# Out:
# {'TIMESTAMP': '11/12/2019 19:07:58 GMT',
#  'VERSION': 2.4,
#  'TRAFFIC_ITEMS': {'TRAFFIC_ITEM': [{'TRAFFIC_ITEM_ID': 908139499033531637,
#     'ORIGINAL_TRAFFIC_ITEM_ID': 908139499033531637,
#     'TRAFFIC_ITEM_STATUS_SHORT_DESC': 'ACTIVE',
#     'TRAFFIC_ITEM_TYPE_DESC': 'ROAD_CLOSURE',
#     'START_TIME': '06/10/2019 19:24:00',
#     'END_TIME': '07/01/2020 00:00:00',
#     'ENTRY_TIME': '11/07/2019 16:08:52',
#     'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#     'VERIFIED': True,
#     'ABBREVIATION': {'SHORT_DESC': 'CLOS', 'DESCRIPTION': ''},
#     'LOCATION': {'INTERSECTION': {'ORIGIN': {'ID': '',
#        'STREET1': {'ADDRESS1': 'Country Club Rd'},
#        'STREET2': {'ADDRESS1': 'Country Club Rd'},
#        'COUNTY': '',
#        'STATE': '',
#        'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#       'TO': {'ID': '',
#        'STREET1': {'ADDRESS1': 'Country Club Rd'},
#        'STREET2': {'ADDRESS1': 'Country Club Rd'},
#        'COUNTY': '',
#        'STATE': '',
#        'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#      'GEOLOC': {'ORIGIN': {'LATITUDE': 35.895263, 'LONGITUDE': -78.319615},
#       'TO': [{'LATITUDE': 35.895263, 'LONGITUDE': -78.319615}],
#       'GEOMETRY': {'SHAPES': {'SHP': [{'value': '35.89247,-78.32005 35.89541,-78.31964',
#           'FC': 5,
#           'LID': '102499546F',
#           'LE': 0.32830740130478275,
#           'FW': 'SD'}]}}},
#      'TPEGOpenLRBase64': 'CC8BEAIrJshORRmGBgAJBQQEAwQACgUEBIZQAAAIAusACQUEBAN9AAAAQII5DAIBAA==',
#      'POLITICAL_BOUNDARY': {'METRO_AREA': {'value': '', 'ID': 65}},
#      'NAVTECH': {'EDGE': {'EDGE_ID': ['102499546']}, 'VERSION_ID': '201904'},
#      'LENGTH': 0.0},
#     'TRAFFIC_ITEM_DETAIL': {'ROAD_CLOSED': True,
#      'INCIDENT': {'RESPONSE_VEHICLES': False,
#       'MISCELLANEOUS_INCIDENT': {'MISCELLANEOUS_TYPE_DESC': ''}},
#      'ALERTC': [{'EVENT_CODE': 401}]},
#     'TRAFFIC_ITEM_DESCRIPTION': [{'value': 'Closed at Country Club Rd - Closed.',
#       'TYPE': 'short_desc'},
#      {'value': 'Closed at Country Club Rd - Closed.', 'TYPE': 'desc'},
#      {'value': 'Closed.', 'TYPE': 'no_exit_description'}],
#     'mid': '567305_original|1573142883617',
#     'PRODUCT': 'basic'},
#    {'TRAFFIC_ITEM_ID': 3442386805610347769,
#     'ORIGINAL_TRAFFIC_ITEM_ID': 3442386805610347769,
#     'TRAFFIC_ITEM_STATUS_SHORT_DESC': 'ACTIVE',
#     'TRAFFIC_ITEM_TYPE_DESC': 'MISCELLANEOUS',
#     'START_TIME': '11/07/2019 16:10:21',
#     'END_TIME': '07/23/2020 03:59:00',
#     'ENTRY_TIME': '11/07/2019 16:10:21',
#     'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#     'VERIFIED': True,
#     'ABBREVIATION': {'SHORT_DESC': 'MISC', 'DESCRIPTION': ''},
#     'LOCATION': {'INTERSECTION': {'ORIGIN': {'ID': '',
#        'STREET1': {'ADDRESS1': 'Selma'},
#        'STREET2': {'ADDRESS1': 'Pine Level'},
#        'COUNTY': 'Johnston',
#        'STATE': '',
#        'PROXIMITY': {'ID': 'MID', 'DESCRIPTION': 'midway between'}},
#       'TO': {'ID': '',
#        'STREET1': {'ADDRESS1': 'Selma'},
#        'STREET2': {'ADDRESS1': 'Pollock St'},
#        'COUNTY': 'Johnston',
#        'STATE': '',
#        'PROXIMITY': {'ID': 'MID', 'DESCRIPTION': 'midway between'}}},
#      'GEOLOC': {'ORIGIN': {'LATITUDE': 35.53995, 'LONGITUDE': -78.2418},
#       'TO': [{'LATITUDE': 35.54067, 'LONGITUDE': -78.24568}],
#       'GEOMETRY': {'SHAPES': {'SHP': [{'value': '35.53995,-78.2418 35.53994,-78.24224 35.53999,-78.24266 35.54026,-78.24361 35.54032,-78.24383 35.54053,-78.24462 35.54067,-78.24568',
#           'FC': 5,
#           'LID': '744009359F',
#           'LE': 0.3633533807831755,
#           'FW': 'SD'}]}}},
#      'TPEGOpenLRBase64': 'CCkBEAAlJMhchBlF2gAJBQQEA8kACgUEBIJrAP58AEgACQUEBANKADAAAA==',
#      'POLITICAL_BOUNDARY': {'METRO_AREA': {'value': '', 'ID': 65},
#       'COUNTY': 'Johnston'},
#      'NAVTECH': {'EDGE': {'EDGE_ID': ['744009359']}, 'VERSION_ID': '201904'},
#      'LENGTH': 0.22577},
#     'TRAFFIC_ITEM_DETAIL': {'ROAD_CLOSED': True,
#      'INCIDENT': {'RESPONSE_VEHICLES': False,
#       'MISCELLANEOUS_INCIDENT': {'MISCELLANEOUS_TYPE_DESC': ''}},
#      'ALERTC': [{'EVENT_CODE': 24}]},
#     'TRAFFIC_ITEM_DESCRIPTION': [{'value': 'Closed between Pine Level and Pollock St - Bridge closed.',
#       'TYPE': 'short_desc'},
#      {'value': 'Closed between Pine Level and Pollock St - Bridge closed.',
#       'TYPE': 'desc'},
#      {'value': 'Bridge closed.', 'TYPE': 'no_exit_description'}],
#     'mid': 'HERE-Non-Europe-PR/r_HERE-Non-Europe-PR/313666_TIC/NAVTEQ_original|1573142989504',
#     'PRODUCT': 'basic'},
#    {'TRAFFIC_ITEM_ID': 3699367173795878760,
#     'ORIGINAL_TRAFFIC_ITEM_ID': 3699367173795878760,
#     'TRAFFIC_ITEM_STATUS_SHORT_DESC': 'ACTIVE',
#     'TRAFFIC_ITEM_TYPE_DESC': 'CONSTRUCTION',
#     'START_TIME': '07/08/2019 14:54:00',
#     'END_TIME': '11/20/2019 16:54:00',
#     'ENTRY_TIME': '11/07/2019 16:08:52',
#     'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#     'VERIFIED': True,
#     'ABBREVIATION': {'SHORT_DESC': 'CONST', 'DESCRIPTION': 'construction'},
#     'LOCATION': {'INTERSECTION': {'ORIGIN': {'ID': '',
#        'STREET1': {'ADDRESS1': 'Pearces Rd.'},
#        'STREET2': {'ADDRESS1': 'Pearces Rd.'},
#        'COUNTY': '',
#        'STATE': '',
#        'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#       'TO': {'ID': '',
#        'STREET1': {'ADDRESS1': 'Pearces Rd.'},
#        'STREET2': {'ADDRESS1': 'Pearces Rd.'},
#        'COUNTY': '',
#        'STATE': '',
#        'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#      'GEOLOC': {'ORIGIN': {'LATITUDE': 35.933946, 'LONGITUDE': -78.296641},
#       'TO': [{'LATITUDE': 35.933946, 'LONGITUDE': -78.296641}],
#       'GEOMETRY': {'SHAPES': {'SHP': [{'value': '35.93038,-78.29973 35.93082,-78.2994 35.93096,-78.29925 35.9312,-78.29897 35.93208,-78.29771 35.93235,-78.29743 35.93265,-78.29719 35.93289,-78.29705 35.93321,-78.29691 35.93574,-78.29612',
#           'FC': 5,
#           'LID': '758986467F',
#           'LE': 0.7000773628984832,
#           'FW': 'SD'}]}}},
#      'TPEGOpenLRBase64': 'CC8BEAIrJshR+BmM7QAJBQQEAxUACgUEBIU8AAFpAhgACQUEBAOVAAAAQINvDAIBAA==',
#      'POLITICAL_BOUNDARY': {'METRO_AREA': {'value': '', 'ID': 65}},
#      'NAVTECH': {'EDGE': {'EDGE_ID': ['758986467']}, 'VERSION_ID': '201904'},
#      'LENGTH': 0.0},
#     'TRAFFIC_ITEM_DETAIL': {'ROAD_CLOSED': True,
#      'EVENT': {'EVENT_ITEM_CANCELLED': False,
#       'SCHEDULED_CONSTRUCTION_EVENT': {'SCHEDULED_CONSTRUCTION_TYPE_DESC': 'CONSTRUCTION',
#        'SCHEDULED_CONSTRUCTION_DETAIL': 'construction'}},
#      'ALERTC': [{'EVENT_CODE': 735}]},
#     'TRAFFIC_ITEM_DESCRIPTION': [{'value': 'Closed at Pearces Rd. - Closed due to roadwork.',
#       'TYPE': 'short_desc'},
#      {'value': 'Closed at Pearces Rd. - Closed due to roadwork.',
#       'TYPE': 'desc'},
#      {'value': 'Closed due to roadwork.', 'TYPE': 'no_exit_description'}],
#     'mid': '569364_original|1573142883609',
#     'PRODUCT': 'basic'},
#    {'TRAFFIC_ITEM_ID': 3302334445572544774,
#     'ORIGINAL_TRAFFIC_ITEM_ID': 3302334445572544774,
#     'TRAFFIC_ITEM_STATUS_SHORT_DESC': 'ACTIVE',
#     'TRAFFIC_ITEM_TYPE_DESC': 'CONSTRUCTION',
#     'START_TIME': '10/28/2019 11:00:00',
#     'END_TIME': '11/15/2019 21:00:00',
#     'ENTRY_TIME': '11/07/2019 16:08:52',
#     'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#     'VERIFIED': True,
#     'ABBREVIATION': {'SHORT_DESC': 'CONST', 'DESCRIPTION': 'construction'},
#     'LOCATION': {'INTERSECTION': {'ORIGIN': {'ID': '',
#        'STREET1': {'ADDRESS1': 'Neuse Rd'},
#        'STREET2': {'ADDRESS1': 'Neuse Rd'},
#        'COUNTY': '',
#        'STATE': '',
#        'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#       'TO': {'ID': '',
#        'STREET1': {'ADDRESS1': 'Neuse Rd'},
#        'STREET2': {'ADDRESS1': 'Neuse Rd'},
#        'COUNTY': '',
#        'STATE': '',
#        'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#      'GEOLOC': {'ORIGIN': {'LATITUDE': 35.119702, 'LONGITUDE': -76.891707},
#       'TO': [{'LATITUDE': 35.119702, 'LONGITUDE': -76.891707}],
#       'GEOMETRY': {'SHAPES': {'SHP': [{'value': '35.11931,-76.89082 35.1195,-76.8912 35.12009,-76.89262 35.12022,-76.8929 35.12034,-76.89311 35.1205,-76.89332 35.12106,-76.89401',
#           'FC': 5,
#           'LID': '125059786F',
#           'LE': 0.3527440057147439,
#           'FW': 'SD'}]}}},
#      'TPEGOpenLRBase64': 'CC4BEAIqJclSdBj5RgAJBQQEA9cACgUEBIJhAP7BAK8ACQUEBANYAAAAQFsMAgEA',
#      'POLITICAL_BOUNDARY': {'METRO_AREA': {'value': '', 'ID': 65}},
#      'NAVTECH': {'EDGE': {'EDGE_ID': ['125059786']}, 'VERSION_ID': '201904'},
#      'LENGTH': 0.0},
#     'TRAFFIC_ITEM_DETAIL': {'ROAD_CLOSED': True,
#      'EVENT': {'EVENT_ITEM_CANCELLED': False,
#       'SCHEDULED_CONSTRUCTION_EVENT': {'SCHEDULED_CONSTRUCTION_TYPE_DESC': 'CONSTRUCTION',
#        'SCHEDULED_CONSTRUCTION_DETAIL': 'construction'}},
#      'ALERTC': [{'EVENT_CODE': 735}]},
#     'TRAFFIC_ITEM_DESCRIPTION': [{'value': 'Closed at Neuse Rd - Closed due to roadwork.',
#       'TYPE': 'short_desc'},
#      {'value': 'Closed at Neuse Rd - Closed due to roadwork.', 'TYPE': 'desc'},
#      {'value': 'Closed due to roadwork.', 'TYPE': 'no_exit_description'}],
#     'mid': '576817_reverse|1573142883618',
#     'PRODUCT': 'basic'},
#    {'TRAFFIC_ITEM_ID': 522410088610993378,
#     'ORIGINAL_TRAFFIC_ITEM_ID': 2137550721157510446,
#     'TRAFFIC_ITEM_STATUS_SHORT_DESC': 'ACTIVE',
#     'TRAFFIC_ITEM_TYPE_DESC': 'CONSTRUCTION',
#     'START_TIME': '06/17/2019 14:00:00',
#     'END_TIME': '12/14/2019 16:00:00',
#     'ENTRY_TIME': '11/08/2019 00:29:49',
#     'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#     'VERIFIED': True,
#     'ABBREVIATION': {'SHORT_DESC': 'CONST', 'DESCRIPTION': 'construction'},
#     'RDS-TMC_LOCATIONS': {'RDS-TMC': [{'ORIGIN': {'EBU_COUNTRY_CODE': '1',
#         'TABLE_ID': 25,
#         'LOCATION_ID': '12722',
#         'LOCATION_DESC': 'US-701',
#         'RDS_DIRECTION': '+'},
#        'DIRECTION': '-',
#        'ALERTC': {'TRAFFIC_CODE': 735,
#         'QUANTIFIERS': 0,
#         'DESCRIPTION': 'Closed due to roadwork.',
#         'ALERTC_DURATION': 'L',
#         'ALERTC_DIRECTION': 1,
#         'URGENCY': 'U',
#         'UPDATE_CLASS': 5,
#         'PHRASE_CODE': 'E1.C1',
#         'EXTENT': '1',
#         'DURATION': 0},
#        'LENGTH': 0.0,
#        'PRIMARY_OFFSET': 3.98128}]},
#     'LOCATION': {'DEFINED': {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'value': 'NC-210',
#           'TYPE': 'NTCSA'},
#          {'value': 'NC-210', 'TYPE': 'RDSGN'},
#          {'value': 'NC-210', 'TYPE': 'LOCAL'}],
#         'ID': 1263},
#        'POINT': {'DESCRIPTION': [{'value': 'US-701', 'TYPE': 'NTCSA'},
#          {'value': 'US-701', 'TYPE': 'RDSGN'},
#          {'value': 'US-701', 'TYPE': 'LOCAL'},
#          {'value': 'NC-210', 'TYPE': 'BNAME'}],
#         'ID': 12722},
#        'DIRECTION': {'DESCRIPTION': [{'value': 'SOUTHBOUND', 'TYPE': 'LOCAL'},
#          {'value': 'SOUTHBOUND', 'TYPE': 'NTCSA'},
#          {'value': 'SOUTHBOUND', 'TYPE': 'RDSGN'}],
#         'ID': 0},
#        'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#       'TO': {'ROADWAY': {'DESCRIPTION': [{'value': 'NC-210', 'TYPE': 'NTCSA'},
#          {'value': 'NC-210', 'TYPE': 'RDSGN'},
#          {'value': 'NC-210', 'TYPE': 'LOCAL'}],
#         'ID': 1263},
#        'POINT': {'DESCRIPTION': [{'value': 'US-701', 'TYPE': 'NTCSA'},
#          {'value': 'US-701', 'TYPE': 'RDSGN'},
#          {'value': 'US-701', 'TYPE': 'LOCAL'},
#          {'value': 'NC-210', 'TYPE': 'BNAME'}],
#         'ID': 12722},
#        'DIRECTION': {'DESCRIPTION': [{'value': 'SOUTHBOUND', 'TYPE': 'LOCAL'},
#          {'value': 'SOUTHBOUND', 'TYPE': 'NTCSA'},
#          {'value': 'SOUTHBOUND', 'TYPE': 'RDSGN'}],
#         'ID': 0},
#        'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#      'GEOLOC': {'ORIGIN': {'LATITUDE': 34.74355, 'LONGITUDE': -78.40795},
#       'TO': [{'LATITUDE': 34.74355, 'LONGITUDE': -78.40795}]},
#      'TPEGOpenLRBase64': 'CC8BEAIrJsg9Vhi1JwAJBQQDA08ACgUEA4sxAAMj/DsACQUEAwP1AAAAQIMcDAIBAA==',
#      'NAVTECH': {'EDGE': {'EDGE_ID': ['102932745']}, 'VERSION_ID': '201904'},
#      'LENGTH': 0.0},
#     'TRAFFIC_ITEM_DETAIL': {'ROAD_CLOSED': True,
#      'EVENT': {'EVENT_ITEM_CANCELLED': False,
#       'SCHEDULED_CONSTRUCTION_EVENT': {'SCHEDULED_CONSTRUCTION_TYPE_DESC': 'CONSTRUCTION',
#        'SCHEDULED_CONSTRUCTION_DETAIL': 'construction'}},
#      'ALERTC': [{'EVENT_CODE': 735}]},
#     'TRAFFIC_ITEM_DESCRIPTION': [{'value': 'Closed at US-701 - Closed due to roadwork.',
#       'TYPE': 'short_desc'},
#      {'value': 'Closed at US-701 - Closed due to roadwork.', 'TYPE': 'desc'},
#      {'value': 'Closed due to roadwork.', 'TYPE': 'no_exit_description'}],
#     'mid': '567831|1573172946675',
#     'PRODUCT': 'basic'},
#    {'TRAFFIC_ITEM_ID': 2529777777645611158,
#     'ORIGINAL_TRAFFIC_ITEM_ID': 201535284923563077,
#     'TRAFFIC_ITEM_STATUS_SHORT_DESC': 'ACTIVE',
#     'TRAFFIC_ITEM_TYPE_DESC': 'ROAD_CLOSURE',
#     'START_TIME': '11/12/2019 14:23:00',
#     'END_TIME': '11/22/2019 22:30:00',
#     'ENTRY_TIME': '11/12/2019 14:44:50',
#     'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#     'VERIFIED': True,
#     'ABBREVIATION': {'SHORT_DESC': 'CLOS', 'DESCRIPTION': ''},
#     'LOCATION': {'INTERSECTION': {'ORIGIN': {'ID': '',
#        'STREET1': {'ADDRESS1': 'Country Club Road'},
#        'STREET2': {'ADDRESS1': 'Country Club Road'},
#        'COUNTY': '',
#        'STATE': '',
#        'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#       'TO': {'ID': '',
#        'STREET1': {'ADDRESS1': 'Country Club Road'},
#        'STREET2': {'ADDRESS1': 'Country Club Road'},
#        'COUNTY': '',
#        'STATE': '',
#        'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#      'GEOLOC': {'ORIGIN': {'LATITUDE': 35.218565, 'LONGITUDE': -78.082289},
#       'TO': [{'LATITUDE': 35.218565, 'LONGITUDE': -78.082289}],
#       'GEOMETRY': {'SHAPES': {'SHP': [{'value': '35.22819,-78.0839 35.22276,-78.08432 35.22252,-78.08432 35.22229,-78.08426 35.22214,-78.0842 35.2199,-78.08301 35.21626,-78.08111 35.21606,-78.08103 35.21581,-78.08096 35.21555,-78.08094 35.21399,-78.08102 35.21263,-78.08109',
#           'FC': 5,
#           'LID': '749405719T',
#           'LE': 1.7892749590998742,
#           'FW': 'SD'}]}}},
#      'TPEGOpenLRBase64': 'CC8BEAIrJsh5QhkNGQAJBQQEA3oACgUEBJAsAAEI+NsACQUEBAMCAAAAQIhVDAIBAA==',
#      'POLITICAL_BOUNDARY': {'METRO_AREA': {'value': '', 'ID': 65}},
#      'NAVTECH': {'EDGE': {'EDGE_ID': ['749405719']}, 'VERSION_ID': '201904'},
#      'LENGTH': 0.0},
#     'TRAFFIC_ITEM_DETAIL': {'ROAD_CLOSED': True,
#      'INCIDENT': {'RESPONSE_VEHICLES': False,
#       'MISCELLANEOUS_INCIDENT': {'MISCELLANEOUS_TYPE_DESC': ''}},
#      'ALERTC': [{'EVENT_CODE': 401}, {'EVENT_CODE': 703}]},
#     'TRAFFIC_ITEM_DESCRIPTION': [{'value': 'Closed at Country Club Road - Closed. Maintenance work.',
#       'TYPE': 'short_desc'},
#      {'value': 'Closed at Country Club Road - Closed. Maintenance work.',
#       'TYPE': 'desc'},
#      {'value': 'Closed. Maintenance work.', 'TYPE': 'no_exit_description'}],
#     'mid': '578801_original|1573569846462',
#     'PRODUCT': 'basic'},
#    {'TRAFFIC_ITEM_ID': 3029310935318399661,
#     'ORIGINAL_TRAFFIC_ITEM_ID': 3029310935318399661,
#     'TRAFFIC_ITEM_STATUS_SHORT_DESC': 'ACTIVE',
#     'TRAFFIC_ITEM_TYPE_DESC': 'CONSTRUCTION',
#     'START_TIME': '05/13/2019 09:00:00',
#     'END_TIME': '05/12/2020 20:00:00',
#     'ENTRY_TIME': '11/07/2019 16:10:21',
#     'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#     'VERIFIED': True,
#     'ABBREVIATION': {'SHORT_DESC': 'CONST', 'DESCRIPTION': 'construction'},
#     'RDS-TMC_LOCATIONS': {'RDS-TMC': [{'ORIGIN': {'EBU_COUNTRY_CODE': '1',
#         'TABLE_ID': 25,
#         'LOCATION_ID': '14729',
#         'LOCATION_DESC': 'Garner Rd',
#         'RDS_DIRECTION': '-'},
#        'DIRECTION': '+',
#        'ALERTC': {'TRAFFIC_CODE': 735,
#         'QUANTIFIERS': 0,
#         'DESCRIPTION': 'Closed due to roadwork.',
#         'ALERTC_DURATION': 'L',
#         'ALERTC_DIRECTION': 1,
#         'URGENCY': 'U',
#         'UPDATE_CLASS': 5,
#         'PHRASE_CODE': 'E1.C1',
#         'EXTENT': '1',
#         'DURATION': 0},
#        'LENGTH': 0.10442,
#        'PRIMARY_OFFSET': 0.99338}]},
#     'LOCATION': {'DEFINED': {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'value': 'Garner Rd',
#           'TYPE': 'NTCSA'},
#          {'value': 'Garner Rd', 'TYPE': 'RDSGN'},
#          {'value': 'Garner Rd', 'TYPE': 'LOCAL'}],
#         'ID': 1654},
#        'POINT': {'DESCRIPTION': [{'value': 'Rush St/Cross Link Rd',
#           'TYPE': 'NTCSA'},
#          {'value': 'Rush St/Cross Link Rd', 'TYPE': 'RDSGN'},
#          {'value': 'Rush St/Cross Link Rd', 'TYPE': 'LOCAL'},
#          {'value': 'Garner Rd', 'TYPE': 'BNAME'}],
#         'ID': 14729},
#        'DIRECTION': {'DESCRIPTION': [{'value': 'WESTBOUND', 'TYPE': 'LOCAL'},
#          {'value': 'WESTBOUND', 'TYPE': 'NTCSA'},
#          {'value': 'WESTBOUND', 'TYPE': 'RDSGN'}],
#         'ID': 0},
#        'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#       'TO': {'ROADWAY': {'DESCRIPTION': [{'value': 'Garner Rd',
#           'TYPE': 'NTCSA'},
#          {'value': 'Garner Rd', 'TYPE': 'RDSGN'},
#          {'value': 'Garner Rd', 'TYPE': 'LOCAL'}],
#         'ID': 1654},
#        'POINT': {'DESCRIPTION': [{'value': 'Garner Rd', 'TYPE': 'NTCSA'},
#          {'value': 'Garner Rd', 'TYPE': 'RDSGN'},
#          {'value': 'Garner Rd', 'TYPE': 'LOCAL'},
#          {'value': 'Garner Rd', 'TYPE': 'BNAME'}],
#         'ID': 14729},
#        'DIRECTION': {'DESCRIPTION': [{'value': 'WESTBOUND', 'TYPE': 'LOCAL'},
#          {'value': 'WESTBOUND', 'TYPE': 'NTCSA'},
#          {'value': 'WESTBOUND', 'TYPE': 'RDSGN'}],
#         'ID': 0},
#        'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#      'GEOLOC': {'ORIGIN': {'LATITUDE': 35.75229, 'LONGITUDE': -78.63119},
#       'TO': [{'LATITUDE': 35.75386, 'LONGITUDE': -78.63124}]},
#      'TPEGOpenLRBase64': 'CCkBEAAlJMgVoRlsggAJBQQDA/8ACgUEA4EpAP/7AJgACQUEAwN/ADAAAA==',
#      'NAVTECH': {'EDGE': {'EDGE_ID': ['880279548', '880279549', '880279550']},
#       'VERSION_ID': '201904'},
#      'LENGTH': 0.10442},
#     'TRAFFIC_ITEM_DETAIL': {'ROAD_CLOSED': True,
#      'EVENT': {'EVENT_ITEM_CANCELLED': False,
#       'SCHEDULED_CONSTRUCTION_EVENT': {'SCHEDULED_CONSTRUCTION_TYPE_DESC': 'CONSTRUCTION',
#        'SCHEDULED_CONSTRUCTION_DETAIL': 'construction'}},
#      'ALERTC': [{'EVENT_CODE': 735}]},
#     'TRAFFIC_ITEM_DESCRIPTION': [{'value': 'Closed at Garner Rd - Closed due to roadwork.',
#       'TYPE': 'short_desc'},
#      {'value': 'Closed at Garner Rd - Closed due to roadwork.',
#       'TYPE': 'desc'},
#      {'value': 'Closed due to roadwork.', 'TYPE': 'no_exit_description'}],
#     'mid': 'HERE-Non-Europe-PR/r_HERE-Non-Europe-PR/241612_TIC/HERE-Non-Europe-PR_reverse|1573142992360',
#     'PRODUCT': 'basic'},
#    {'TRAFFIC_ITEM_ID': 3379088812521848735,
#     'ORIGINAL_TRAFFIC_ITEM_ID': 3379088812521848735,
#     'TRAFFIC_ITEM_STATUS_SHORT_DESC': 'ACTIVE',
#     'TRAFFIC_ITEM_TYPE_DESC': 'ROAD_CLOSURE',
#     'START_TIME': '06/10/2019 19:24:00',
#     'END_TIME': '07/01/2020 00:00:00',
#     'ENTRY_TIME': '11/07/2019 16:08:52',
#     'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#     'VERIFIED': True,
#     'ABBREVIATION': {'SHORT_DESC': 'CLOS', 'DESCRIPTION': ''},
#     'LOCATION': {'INTERSECTION': {'ORIGIN': {'ID': '',
#        'STREET1': {'ADDRESS1': 'Country Club Rd'},
#        'STREET2': {'ADDRESS1': 'Country Club Rd'},
#        'COUNTY': '',
#        'STATE': '',
#        'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#       'TO': {'ID': '',
#        'STREET1': {'ADDRESS1': 'Country Club Rd'},
#        'STREET2': {'ADDRESS1': 'Country Club Rd'},
#        'COUNTY': '',
#        'STATE': '',
#        'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#      'GEOLOC': {'ORIGIN': {'LATITUDE': 35.895263, 'LONGITUDE': -78.319615},
#       'TO': [{'LATITUDE': 35.895263, 'LONGITUDE': -78.319615}],
#       'GEOMETRY': {'SHAPES': {'SHP': [{'value': '35.89541,-78.31964 35.89247,-78.32005',
#           'FC': 5,
#           'LID': '102499546T',
#           'LE': 0.32830740130478275,
#           'FW': 'SD'}]}}},
#      'TPEGOpenLRBase64': 'CC8BEAIrJshOSRmHYgAJBQQEA30ACgUEBIZQAP/4/RUACQUEBAMEAAAAQIQXDAIBAA==',
#      'POLITICAL_BOUNDARY': {'METRO_AREA': {'value': '', 'ID': 65}},
#      'NAVTECH': {'EDGE': {'EDGE_ID': ['102499546']}, 'VERSION_ID': '201904'},
#      'LENGTH': 0.0},
#     'TRAFFIC_ITEM_DETAIL': {'ROAD_CLOSED': True,
#      'INCIDENT': {'RESPONSE_VEHICLES': False,
#       'MISCELLANEOUS_INCIDENT': {'MISCELLANEOUS_TYPE_DESC': ''}},
#      'ALERTC': [{'EVENT_CODE': 401}]},
#     'TRAFFIC_ITEM_DESCRIPTION': [{'value': 'Closed at Country Club Rd - Closed.',
#       'TYPE': 'short_desc'},
#      {'value': 'Closed at Country Club Rd - Closed.', 'TYPE': 'desc'},
#      {'value': 'Closed.', 'TYPE': 'no_exit_description'}],
#     'mid': '567305_reverse|1573142883617',
#     'PRODUCT': 'basic'},
#    {'TRAFFIC_ITEM_ID': 3449892200566307217,
#     'ORIGINAL_TRAFFIC_ITEM_ID': 553382698492276120,
#     'TRAFFIC_ITEM_STATUS_SHORT_DESC': 'ACTIVE',
#     'TRAFFIC_ITEM_TYPE_DESC': 'ROAD_CLOSURE',
#     'START_TIME': '10/21/2019 13:00:00',
#     'END_TIME': '11/15/2019 22:00:00',
#     'ENTRY_TIME': '11/08/2019 00:29:49',
#     'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#     'VERIFIED': True,
#     'ABBREVIATION': {'SHORT_DESC': 'CLOS', 'DESCRIPTION': ''},
#     'LOCATION': {'INTERSECTION': {'ORIGIN': {'ID': '',
#        'STREET1': {'ADDRESS1': 'Moltonville Rd'},
#        'STREET2': {'ADDRESS1': 'Moltonville Rd'},
#        'COUNTY': '',
#        'STATE': '',
#        'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#       'TO': {'ID': '',
#        'STREET1': {'ADDRESS1': 'Moltonville Rd'},
#        'STREET2': {'ADDRESS1': 'Moltonville Rd'},
#        'COUNTY': '',
#        'STATE': '',
#        'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#      'GEOLOC': {'ORIGIN': {'LATITUDE': 35.003934, 'LONGITUDE': -78.249907},
#       'TO': [{'LATITUDE': 35.003934, 'LONGITUDE': -78.249907}],
#       'GEOMETRY': {'SHAPES': {'SHP': [{'value': '35.00244,-78.24974 35.00294,-78.24978 35.00478,-78.25002 35.00603,-78.25016',
#           'FC': 5,
#           'LID': '102864115F',
#           'LE': 0.4001570953278164,
#           'FW': 'SD'}]}}},
#      'TPEGOpenLRBase64': 'CC8BEAIrJshbEhjkAAAJBQQEA/wACgUEBIMQAP/WAWcACQUEBAN8AAAAQIEmDAIBAA==',
#      'POLITICAL_BOUNDARY': {'METRO_AREA': {'value': '', 'ID': 65}},
#      'NAVTECH': {'EDGE': {'EDGE_ID': ['102864115']}, 'VERSION_ID': '201904'},
#      'LENGTH': 0.0},
#     'TRAFFIC_ITEM_DETAIL': {'ROAD_CLOSED': True,
#      'INCIDENT': {'RESPONSE_VEHICLES': False,
#       'MISCELLANEOUS_INCIDENT': {'MISCELLANEOUS_TYPE_DESC': ''}},
#      'ALERTC': [{'EVENT_CODE': 401}, {'EVENT_CODE': 703}]},
#     'TRAFFIC_ITEM_DESCRIPTION': [{'value': 'Closed at Moltonville Rd - Closed. Maintenance work.',
#       'TYPE': 'short_desc'},
#      {'value': 'Closed at Moltonville Rd - Closed. Maintenance work.',
#       'TYPE': 'desc'},
#      {'value': 'Closed. Maintenance work.', 'TYPE': 'no_exit_description'}],
#     'mid': '576881_reverse|1573172946675',
#     'PRODUCT': 'basic'},
#    {'TRAFFIC_ITEM_ID': 2523397910974926556,
#     'ORIGINAL_TRAFFIC_ITEM_ID': 651774794922526670,
#     'TRAFFIC_ITEM_STATUS_SHORT_DESC': 'ACTIVE',
#     'TRAFFIC_ITEM_TYPE_DESC': 'CONSTRUCTION',
#     'START_TIME': '05/06/2019 12:00:00',
#     'END_TIME': '11/22/2019 23:00:00',
#     'ENTRY_TIME': '11/08/2019 00:29:49',
#     'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#     'VERIFIED': True,
#     'ABBREVIATION': {'SHORT_DESC': 'CONST', 'DESCRIPTION': 'construction'},
#     'LOCATION': {'INTERSECTION': {'ORIGIN': {'ID': '',
#        'STREET1': {'ADDRESS1': 'Old Route 22 Rd'},
#        'STREET2': {'ADDRESS1': 'Old Route 22 Rd'},
#        'COUNTY': '',
#        'STATE': '',
#        'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#       'TO': {'ID': '',
#        'STREET1': {'ADDRESS1': 'Old Route 22 Rd'},
#        'STREET2': {'ADDRESS1': 'Old Route 22 Rd'},
#        'COUNTY': '',
#        'STATE': '',
#        'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#      'GEOLOC': {'ORIGIN': {'LATITUDE': 35.596422, 'LONGITUDE': -78.163493},
#       'TO': [{'LATITUDE': 35.596422, 'LONGITUDE': -78.163493}],
#       'GEOMETRY': {'SHAPES': {'SHP': [{'value': '35.5965,-78.16339 35.59648,-78.16346 35.59642,-78.16368',
#           'FC': 4,
#           'LID': '1159195967T',
#           'LE': 0.027738825714189758,
#           'FW': 'SD'}]}}},
#      'TPEGOpenLRBase64': 'CC8BEAIrJshreBlQPwAJBQQDA7kACgUEA4kKAPti/pAACQUEAwMoAAAAQIJkDAIBAA==',
#      'POLITICAL_BOUNDARY': {'METRO_AREA': {'value': '', 'ID': 65}},
#      'NAVTECH': {'EDGE': {'EDGE_ID': ['1159195967']}, 'VERSION_ID': '201904'},
#      'LENGTH': 0.0},
#     'TRAFFIC_ITEM_DETAIL': {'ROAD_CLOSED': True,
#      'EVENT': {'EVENT_ITEM_CANCELLED': False,
#       'SCHEDULED_CONSTRUCTION_EVENT': {'SCHEDULED_CONSTRUCTION_TYPE_DESC': 'CONSTRUCTION',
#        'SCHEDULED_CONSTRUCTION_DETAIL': 'construction'}},
#      'ALERTC': [{'EVENT_CODE': 735}]},
#     'TRAFFIC_ITEM_DESCRIPTION': [{'value': 'Closed at Old Route 22 Rd - Closed due to roadwork.',
#       'TYPE': 'short_desc'},
#      {'value': 'Closed at Old Route 22 Rd - Closed due to roadwork.',
#       'TYPE': 'desc'},
#      {'value': 'Closed due to roadwork.', 'TYPE': 'no_exit_description'}],
#     'mid': '563678_reverse|1573172946675',
#     'PRODUCT': 'basic'},
#    {'TRAFFIC_ITEM_ID': 2195858463199493519,
#     'ORIGINAL_TRAFFIC_ITEM_ID': 2195858463199493519,
#     'TRAFFIC_ITEM_STATUS_SHORT_DESC': 'ACTIVE',
#     'TRAFFIC_ITEM_TYPE_DESC': 'CONSTRUCTION',
#     'START_TIME': '07/22/2019 11:00:00',
#     'END_TIME': '12/27/2019 22:00:00',
#     'ENTRY_TIME': '11/07/2019 16:08:52',
#     'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#     'VERIFIED': True,
#     'ABBREVIATION': {'SHORT_DESC': 'CONST', 'DESCRIPTION': 'construction'},
#     'RDS-TMC_LOCATIONS': {'RDS-TMC': [{'ORIGIN': {'EBU_COUNTRY_CODE': '1',
#         'TABLE_ID': 25,
#         'LOCATION_ID': '15172',
#         'LOCATION_DESC': 'Belgrade Swansboro Rd',
#         'RDS_DIRECTION': '-'},
#        'DIRECTION': '+',
#        'ALERTC': {'TRAFFIC_CODE': 735,
#         'QUANTIFIERS': 0,
#         'DESCRIPTION': 'Closed due to roadwork.',
#         'ALERTC_DURATION': 'L',
#         'ALERTC_DIRECTION': 1,
#         'URGENCY': 'U',
#         'UPDATE_CLASS': 5,
#         'PHRASE_CODE': 'E1.C1',
#         'EXTENT': '1',
#         'DURATION': 0},
#        'LENGTH': 0.0,
#        'PRIMARY_OFFSET': 6.2913}]},
#     'LOCATION': {'DEFINED': {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'value': 'Belgrade Swansboro Rd',
#           'TYPE': 'NTCSA'},
#          {'value': 'Belgrade Swansboro Rd', 'TYPE': 'RDSGN'},
#          {'value': 'Belgrade Swansboro Rd', 'TYPE': 'LOCAL'}],
#         'ID': 1751},
#        'POINT': {'DESCRIPTION': [{'value': 'Belgrade Swansboro Rd',
#           'TYPE': 'NTCSA'},
#          {'value': 'Belgrade Swansboro Rd', 'TYPE': 'RDSGN'},
#          {'value': 'Belgrade Swansboro Rd', 'TYPE': 'LOCAL'},
#          {'value': 'Belgrade Swansboro Rd', 'TYPE': 'BNAME'}],
#         'ID': 15172},
#        'DIRECTION': {'DESCRIPTION': [{'value': 'NORTHBOUND', 'TYPE': 'LOCAL'},
#          {'value': 'NORTHBOUND', 'TYPE': 'NTCSA'},
#          {'value': 'NORTHBOUND', 'TYPE': 'RDSGN'}],
#         'ID': 0},
#        'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#       'TO': {'ROADWAY': {'DESCRIPTION': [{'value': 'Belgrade Swansboro Rd',
#           'TYPE': 'NTCSA'},
#          {'value': 'Belgrade Swansboro Rd', 'TYPE': 'RDSGN'},
#          {'value': 'Belgrade Swansboro Rd', 'TYPE': 'LOCAL'}],
#         'ID': 1751},
#        'POINT': {'DESCRIPTION': [{'value': 'Belgrade Swansboro Rd',
#           'TYPE': 'NTCSA'},
#          {'value': 'Belgrade Swansboro Rd', 'TYPE': 'RDSGN'},
#          {'value': 'Belgrade Swansboro Rd', 'TYPE': 'LOCAL'},
#          {'value': 'Belgrade Swansboro Rd', 'TYPE': 'BNAME'}],
#         'ID': 15172},
#        'DIRECTION': {'DESCRIPTION': [{'value': 'NORTHBOUND', 'TYPE': 'LOCAL'},
#          {'value': 'NORTHBOUND', 'TYPE': 'NTCSA'},
#          {'value': 'NORTHBOUND', 'TYPE': 'RDSGN'}],
#         'ID': 0},
#        'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#      'GEOLOC': {'ORIGIN': {'LATITUDE': 34.79869, 'LONGITUDE': -77.21341},
#       'TO': [{'LATITUDE': 34.79869, 'LONGITUDE': -77.21341}]},
#      'TPEGOpenLRBase64': 'CC8BEAIrJskX7xi+aAAJBQQDA/kACgUEA4NNAP85AXEACQUEAwNuAAAAQIJCDAIBAA==',
#      'NAVTECH': {'EDGE': {'EDGE_ID': ['1183380943']}, 'VERSION_ID': '201904'},
#      'LENGTH': 0.0},
#     'TRAFFIC_ITEM_DETAIL': {'ROAD_CLOSED': True,
#      'EVENT': {'EVENT_ITEM_CANCELLED': False,
#       'SCHEDULED_CONSTRUCTION_EVENT': {'SCHEDULED_CONSTRUCTION_TYPE_DESC': 'CONSTRUCTION',
#        'SCHEDULED_CONSTRUCTION_DETAIL': 'construction'}},
#      'ALERTC': [{'EVENT_CODE': 735}]},
#     'TRAFFIC_ITEM_DESCRIPTION': [{'value': 'Closed at Belgrade Swansboro Rd - Closed due to roadwork.',
#       'TYPE': 'short_desc'},
#      {'value': 'Closed at Belgrade Swansboro Rd - Closed due to roadwork.',
#       'TYPE': 'desc'},
#      {'value': 'Closed due to roadwork.', 'TYPE': 'no_exit_description'}],
#     'mid': '570372_reverse|1573142883604',
#     'PRODUCT': 'basic'},
#    {'TRAFFIC_ITEM_ID': 1077625086103944653,
#     'ORIGINAL_TRAFFIC_ITEM_ID': 499811481550737002,
#     'TRAFFIC_ITEM_STATUS_SHORT_DESC': 'ACTIVE',
#     'TRAFFIC_ITEM_TYPE_DESC': 'CONSTRUCTION',
#     'START_TIME': '11/02/2019 11:30:00',
#     'END_TIME': '08/28/2020 21:00:00',
#     'ENTRY_TIME': '11/08/2019 00:29:49',
#     'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#     'VERIFIED': True,
#     'ABBREVIATION': {'SHORT_DESC': 'CONST', 'DESCRIPTION': 'construction'},
#     'LOCATION': {'INTERSECTION': {'ORIGIN': {'ID': '',
#        'STREET1': {'ADDRESS1': 'Kornegay Town Rd'},
#        'STREET2': {'ADDRESS1': 'Kornegay Town Rd'},
#        'COUNTY': '',
#        'STATE': '',
#        'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#       'TO': {'ID': '',
#        'STREET1': {'ADDRESS1': 'Kornegay Town Rd'},
#        'STREET2': {'ADDRESS1': 'Kornegay Town Rd'},
#        'COUNTY': '',
#        'STATE': '',
#        'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#      'GEOLOC': {'ORIGIN': {'LATITUDE': 35.225699, 'LONGITUDE': -78.336017},
#       'TO': [{'LATITUDE': 35.225699, 'LONGITUDE': -78.336017}],
#       'GEOMETRY': {'SHAPES': {'SHP': [{'value': '35.2203,-78.32882 35.22044,-78.32963 35.22066,-78.33022 35.22098,-78.33086 35.22138,-78.33144 35.2261,-78.33646 35.22636,-78.33668 35.22803,-78.33785 35.22851,-78.33812 35.22976,-78.33873 35.2301,-78.33892 35.23038,-78.3391 35.23129,-78.33987 35.23228,-78.34074',
#           'FC': 5,
#           'LID': '1105530312F',
#           'LE': 1.7584127931193623,
#           'FW': 'SD'}]}}},
#      'TPEGOpenLRBase64': 'CC8BEAIrJshMrBkLqQAJBQQEA+QACgUEBI1eAPtYBK4ACQUEBANkAAAAQIcKDAIBAA==',
#      'POLITICAL_BOUNDARY': {'METRO_AREA': {'value': '', 'ID': 65}},
#      'NAVTECH': {'EDGE': {'EDGE_ID': ['1105530312']}, 'VERSION_ID': '201904'},
#      'LENGTH': 0.0},
#     'TRAFFIC_ITEM_DETAIL': {'ROAD_CLOSED': True,
#      'EVENT': {'EVENT_ITEM_CANCELLED': False,
#       'SCHEDULED_CONSTRUCTION_EVENT': {'SCHEDULED_CONSTRUCTION_TYPE_DESC': 'CONSTRUCTION',
#        'SCHEDULED_CONSTRUCTION_DETAIL': 'construction'}},
#      'ALERTC': [{'EVENT_CODE': 735}]},
#     'TRAFFIC_ITEM_DESCRIPTION': [{'value': 'Closed at Kornegay Town Rd - Closed due to roadwork.',
#       'TYPE': 'short_desc'},
#      {'value': 'Closed at Kornegay Town Rd - Closed due to roadwork.',
#       'TYPE': 'desc'},
#      {'value': 'Closed due to roadwork.', 'TYPE': 'no_exit_description'}],
#     'mid': '577505_original|1573172946675',
#     'PRODUCT': 'basic'},
#    {'TRAFFIC_ITEM_ID': 770248056005413625,
#     'ORIGINAL_TRAFFIC_ITEM_ID': 770248056005413625,
#     'TRAFFIC_ITEM_STATUS_SHORT_DESC': 'ACTIVE',
#     'TRAFFIC_ITEM_TYPE_DESC': 'CONSTRUCTION',
#     'START_TIME': '05/29/2019 10:00:00',
#     'END_TIME': '05/29/2020 21:00:00',
#     'ENTRY_TIME': '11/07/2019 16:08:52',
#     'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#     'VERIFIED': True,
#     'ABBREVIATION': {'SHORT_DESC': 'CONST', 'DESCRIPTION': 'construction'},
#     'RDS-TMC_LOCATIONS': {'RDS-TMC': [{'ORIGIN': {'EBU_COUNTRY_CODE': '1',
#         'TABLE_ID': 25,
#         'LOCATION_ID': '14722',
#         'LOCATION_DESC': 'E Garner Rd',
#         'RDS_DIRECTION': '+'},
#        'DIRECTION': '-',
#        'ALERTC': {'TRAFFIC_CODE': 735,
#         'QUANTIFIERS': 0,
#         'DESCRIPTION': 'Closed due to roadwork.',
#         'ALERTC_DURATION': 'L',
#         'ALERTC_DIRECTION': 1,
#         'URGENCY': 'U',
#         'UPDATE_CLASS': 5,
#         'PHRASE_CODE': 'E1.C1',
#         'EXTENT': '1',
#         'DURATION': 0},
#        'LENGTH': 0.0,
#        'PRIMARY_OFFSET': 1.9216}]},
#     'LOCATION': {'DEFINED': {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'value': 'E Garner Rd',
#           'TYPE': 'NTCSA'},
#          {'value': 'E Garner Rd', 'TYPE': 'RDSGN'},
#          {'value': 'E Garner Rd', 'TYPE': 'LOCAL'}],
#         'ID': 1654},
#        'POINT': {'DESCRIPTION': [{'value': 'E Garner Rd', 'TYPE': 'NTCSA'},
#          {'value': 'E Garner Rd', 'TYPE': 'RDSGN'},
#          {'value': 'E Garner Rd', 'TYPE': 'LOCAL'},
#          {'value': 'E Garner Rd', 'TYPE': 'BNAME'}],
#         'ID': 14722},
#        'DIRECTION': {'DESCRIPTION': [{'value': 'EASTBOUND', 'TYPE': 'LOCAL'},
#          {'value': 'EASTBOUND', 'TYPE': 'NTCSA'},
#          {'value': 'EASTBOUND', 'TYPE': 'RDSGN'}],
#         'ID': 0},
#        'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#       'TO': {'ROADWAY': {'DESCRIPTION': [{'value': 'E Garner Rd',
#           'TYPE': 'NTCSA'},
#          {'value': 'E Garner Rd', 'TYPE': 'RDSGN'},
#          {'value': 'E Garner Rd', 'TYPE': 'LOCAL'}],
#         'ID': 1654},
#        'POINT': {'DESCRIPTION': [{'value': 'E Garner Rd', 'TYPE': 'NTCSA'},
#          {'value': 'E Garner Rd', 'TYPE': 'RDSGN'},
#          {'value': 'E Garner Rd', 'TYPE': 'LOCAL'},
#          {'value': 'E Garner Rd', 'TYPE': 'BNAME'}],
#         'ID': 14722},
#        'DIRECTION': {'DESCRIPTION': [{'value': 'EASTBOUND', 'TYPE': 'LOCAL'},
#          {'value': 'EASTBOUND', 'TYPE': 'NTCSA'},
#          {'value': 'EASTBOUND', 'TYPE': 'RDSGN'}],
#         'ID': 0},
#        'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#      'GEOLOC': {'ORIGIN': {'LATITUDE': 35.7024, 'LONGITUDE': -78.58124},
#       'TO': [{'LATITUDE': 35.7024, 'LONGITUDE': -78.58124}]},
#      'TPEGOpenLRBase64': 'CC8BEAIrJsgeNxljfAAJBQQDA0YACgUEA5EAAAj9/fwACQUEAwPQAAAAQIMDDAIBAA==',
#      'NAVTECH': {'EDGE': {'EDGE_ID': ['1209045054']}, 'VERSION_ID': '201904'},
#      'LENGTH': 0.0},
#     'TRAFFIC_ITEM_DETAIL': {'ROAD_CLOSED': True,
#      'EVENT': {'EVENT_ITEM_CANCELLED': False,
#       'SCHEDULED_CONSTRUCTION_EVENT': {'SCHEDULED_CONSTRUCTION_TYPE_DESC': 'CONSTRUCTION',
#        'SCHEDULED_CONSTRUCTION_DETAIL': 'construction'}},
#      'ALERTC': [{'EVENT_CODE': 735}]},
#     'TRAFFIC_ITEM_DESCRIPTION': [{'value': 'Closed at E Garner Rd - Closed due to roadwork.',
#       'TYPE': 'short_desc'},
#      {'value': 'Closed at E Garner Rd - Closed due to roadwork.',
#       'TYPE': 'desc'},
#      {'value': 'Closed due to roadwork.', 'TYPE': 'no_exit_description'}],
#     'mid': '563094_reverse|1573142883619',
#     'PRODUCT': 'basic'},
#    {'TRAFFIC_ITEM_ID': 4374909359015640594,
#     'ORIGINAL_TRAFFIC_ITEM_ID': 4374909359015640594,
#     'TRAFFIC_ITEM_STATUS_SHORT_DESC': 'ACTIVE',
#     'TRAFFIC_ITEM_TYPE_DESC': 'ROAD_CLOSURE',
#     'START_TIME': '07/26/2019 00:15:00',
#     'END_TIME': '05/31/2020 04:00:00',
#     'ENTRY_TIME': '11/07/2019 16:08:52',
#     'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#     'VERIFIED': True,
#     'ABBREVIATION': {'SHORT_DESC': 'CLOS', 'DESCRIPTION': ''},
#     'LOCATION': {'INTERSECTION': {'ORIGIN': {'ID': '',
#        'STREET1': {'ADDRESS1': 'Pete Smith Rd'},
#        'STREET2': {'ADDRESS1': 'Pete Smith Rd'},
#        'COUNTY': '',
#        'STATE': '',
#        'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#       'TO': {'ID': '',
#        'STREET1': {'ADDRESS1': 'Pete Smith Rd'},
#        'STREET2': {'ADDRESS1': 'Pete Smith Rd'},
#        'COUNTY': '',
#        'STATE': '',
#        'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#      'GEOLOC': {'ORIGIN': {'LATITUDE': 36.201258, 'LONGITUDE': -78.238257},
#       'TO': [{'LATITUDE': 36.201258, 'LONGITUDE': -78.238257}],
#       'GEOMETRY': {'SHAPES': {'SHP': [{'value': '36.20128,-78.23826 36.20025,-78.23862 36.19992,-78.23872 36.19958,-78.23878 36.19751,-78.23899 36.19682,-78.239 36.19568,-78.23891 36.19506,-78.23894 36.19384,-78.23913',
#           'FC': 5,
#           'LID': '810740087T',
#           'LE': 0.8336984431408527,
#           'FW': 'SD'}]}}},
#      'TPEGOpenLRBase64': 'CC8BEAIrJshd0Bm/CgAJBQQEA5gACgUEBIsQAP5C+2MACQUEBAMEAAAAQIRQDAIBAA==',
#      'POLITICAL_BOUNDARY': {'METRO_AREA': {'value': '', 'ID': 65}},
#      'NAVTECH': {'EDGE': {'EDGE_ID': ['810740087']}, 'VERSION_ID': '201904'},
#      'LENGTH': 0.0},
#     'TRAFFIC_ITEM_DETAIL': {'ROAD_CLOSED': True,
#      'INCIDENT': {'RESPONSE_VEHICLES': False,
#       'MISCELLANEOUS_INCIDENT': {'MISCELLANEOUS_TYPE_DESC': ''}},
#      'ALERTC': [{'EVENT_CODE': 401}, {'EVENT_CODE': 703}]},
#     'TRAFFIC_ITEM_DESCRIPTION': [{'value': 'Closed at Pete Smith Rd - Closed. Maintenance work.',
#       'TYPE': 'short_desc'},
#      {'value': 'Closed at Pete Smith Rd - Closed. Maintenance work.',
#       'TYPE': 'desc'},
#      {'value': 'Closed. Maintenance work.', 'TYPE': 'no_exit_description'}],
#     'mid': '557364_reverse|1573142883604',
#     'PRODUCT': 'basic'},
#    {'TRAFFIC_ITEM_ID': 2823567405818011171,
#     'ORIGINAL_TRAFFIC_ITEM_ID': 1486649337702488191,
#     'TRAFFIC_ITEM_STATUS_SHORT_DESC': 'ACTIVE',
#     'TRAFFIC_ITEM_TYPE_DESC': 'CONSTRUCTION',
#     'START_TIME': '11/12/2019 18:11:49',
#     'END_TIME': '11/12/2019 23:09:52',
#     'ENTRY_TIME': '11/12/2019 18:11:49',
#     'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#     'VERIFIED': True,
#     'ABBREVIATION': {'SHORT_DESC': 'CONST', 'DESCRIPTION': 'construction'},
#     'LOCATION': {'INTERSECTION': {'ORIGIN': {'ID': '',
#        'STREET1': {'ADDRESS1': 'Hallsboro Rd S'},
#        'STREET2': {'ADDRESS1': 'Lake Waccamaw'},
#        'COUNTY': 'Columbus',
#        'STATE': '',
#        'PROXIMITY': {'ID': 'MID', 'DESCRIPTION': 'midway between'}},
#       'TO': {'ID': '',
#        'STREET1': {'ADDRESS1': 'Whiteville'},
#        'STREET2': {'ADDRESS1': 'Whiteville'},
#        'COUNTY': 'Columbus',
#        'STATE': '',
#        'PROXIMITY': {'ID': 'MID', 'DESCRIPTION': 'midway between'}}},
#      'GEOLOC': {'ORIGIN': {'LATITUDE': 34.21948, 'LONGITUDE': -78.6181},
#       'TO': [{'LATITUDE': 34.20031, 'LONGITUDE': -78.60888}],
#       'GEOMETRY': {'SHAPES': {'SHP': [{'value': '34.21948,-78.6181 34.21879,-78.61766 34.21821,-78.61729 34.21792,-78.61706 34.21737,-78.6165 34.21519,-78.61399 34.21191,-78.61021',
#           'FC': 5,
#           'LID': '916299494T',
#           'LE': 1.1161877052789806,
#           'FW': 'SD'},
#          {'value': '34.21191,-78.61021 34.21148,-78.60971 34.2111,-78.6093 34.2109,-78.60911 34.21067,-78.60897 34.21043,-78.60889 34.20967,-78.6087 34.20782,-78.6083 34.20706,-78.60813 34.20678,-78.6081 34.20651,-78.6081 34.20557,-78.60827 34.2038,-78.60849 34.20031,-78.60888',
#           'FC': 5,
#           'LID': '916299493T',
#           'LE': 1.3405062698919392,
#           'FW': 'SD'}]}}},
#      'TPEGOpenLRBase64': 'CCkBEAAlJMgYAxhVdwAJBQQEA2MACgUEBJMZAAOa+IMACQUEBAP8ADAAAA==',
#      'POLITICAL_BOUNDARY': {'METRO_AREA': {'value': '', 'ID': 65},
#       'COUNTY': 'Columbus'},
#      'NAVTECH': {'EDGE': {'EDGE_ID': ['916299494', '916299493']},
#       'VERSION_ID': '201904'},
#      'LENGTH': 1.52651},
#     'TRAFFIC_ITEM_DETAIL': {'ROAD_CLOSED': True,
#      'EVENT': {'EVENT_ITEM_CANCELLED': False,
#       'SCHEDULED_CONSTRUCTION_EVENT': {'SCHEDULED_CONSTRUCTION_TYPE_DESC': 'CONSTRUCTION',
#        'SCHEDULED_CONSTRUCTION_DETAIL': 'construction'}},
#      'ALERTC': [{'EVENT_CODE': 735}]},
#     'TRAFFIC_ITEM_DESCRIPTION': [{'value': 'Closed between Lake Waccamaw and Whiteville - Closed due to roadwork.',
#       'TYPE': 'short_desc'},
#      {'value': 'Closed between Lake Waccamaw and Whiteville - Closed due to roadwork.',
#       'TYPE': 'desc'},
#      {'value': 'Closed due to roadwork.', 'TYPE': 'no_exit_description'}],
#     'mid': 'NAVTEQ/r_NAVTEQ/11180955_TIC/NAVTEQ_original|1573582276018',
#     'PRODUCT': 'basic'},
#    {'TRAFFIC_ITEM_ID': 470846632630009821,
#     'ORIGINAL_TRAFFIC_ITEM_ID': 293380546745631881,
#     'TRAFFIC_ITEM_STATUS_SHORT_DESC': 'ACTIVE',
#     'TRAFFIC_ITEM_TYPE_DESC': 'ROAD_CLOSURE',
#     'START_TIME': '11/11/2019 13:00:00',
#     'END_TIME': '11/25/2019 23:00:00',
#     'ENTRY_TIME': '11/11/2019 13:27:35',
#     'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#     'VERIFIED': True,
#     'ABBREVIATION': {'SHORT_DESC': 'CLOS', 'DESCRIPTION': ''},
#     'LOCATION': {'INTERSECTION': {'ORIGIN': {'ID': '',
#        'STREET1': {'ADDRESS1': 'Nahunta Road'},
#        'STREET2': {'ADDRESS1': 'Nahunta Road'},
#        'COUNTY': '',
#        'STATE': '',
#        'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#       'TO': {'ID': '',
#        'STREET1': {'ADDRESS1': 'Nahunta Road'},
#        'STREET2': {'ADDRESS1': 'Nahunta Road'},
#        'COUNTY': '',
#        'STATE': '',
#        'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#      'GEOLOC': {'ORIGIN': {'LATITUDE': 35.489454, 'LONGITUDE': -77.998155},
#       'TO': [{'LATITUDE': 35.489454, 'LONGITUDE': -77.998155}],
#       'GEOMETRY': {'SHAPES': {'SHP': [{'value': '35.47871,-77.99265 35.47973,-77.99278 35.48196,-77.99347 35.48497,-77.99407 35.48533,-77.99423 35.48644,-77.9956 35.48663,-77.99581 35.48691,-77.99608 35.48895,-77.99779 35.49227,-78.00015 35.49311,-78.00064 35.49329,-78.00071',
#           'FC': 5,
#           'LID': '716816757F',
#           'LE': 1.8175572376479125,
#           'FW': 'SD'}]}}},
#      'TPEGOpenLRBase64': 'CC8BEAIrJsiJ3xk6tAAJBQQEA+8ACgUEBI4aAPzaBbIACQUEBANvAAAAQIo2DAIBAA==',
#      'POLITICAL_BOUNDARY': {'METRO_AREA': {'value': '', 'ID': 65}},
#      'NAVTECH': {'EDGE': {'EDGE_ID': ['716816757']}, 'VERSION_ID': '201904'},
#      'LENGTH': 0.0},
#     'TRAFFIC_ITEM_DETAIL': {'ROAD_CLOSED': True,
#      'INCIDENT': {'RESPONSE_VEHICLES': False,
#       'MISCELLANEOUS_INCIDENT': {'MISCELLANEOUS_TYPE_DESC': ''}},
#      'ALERTC': [{'EVENT_CODE': 401}, {'EVENT_CODE': 703}]},
#     'TRAFFIC_ITEM_DESCRIPTION': [{'value': 'Closed at Nahunta Road - Closed. Maintenance work.',
#       'TYPE': 'short_desc'},
#      {'value': 'Closed at Nahunta Road - Closed. Maintenance work.',
#       'TYPE': 'desc'},
#      {'value': 'Closed. Maintenance work.', 'TYPE': 'no_exit_description'}],
#     'mid': '578611_original|1573478826436',
#     'PRODUCT': 'basic'},
#    {'TRAFFIC_ITEM_ID': 377797166426428411,
#     'ORIGINAL_TRAFFIC_ITEM_ID': 3632339974544983405,
#     'TRAFFIC_ITEM_STATUS_SHORT_DESC': 'ACTIVE',
#     'TRAFFIC_ITEM_TYPE_DESC': 'CONSTRUCTION',
#     'START_TIME': '11/12/2019 18:11:49',
#     'END_TIME': '11/12/2019 23:09:52',
#     'ENTRY_TIME': '11/12/2019 18:11:49',
#     'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#     'VERIFIED': True,
#     'ABBREVIATION': {'SHORT_DESC': 'CONST', 'DESCRIPTION': 'construction'},
#     'LOCATION': {'INTERSECTION': {'ORIGIN': {'ID': '',
#        'STREET1': {'ADDRESS1': 'Whiteville'},
#        'STREET2': {'ADDRESS1': 'Whiteville'},
#        'COUNTY': 'Columbus',
#        'STATE': '',
#        'PROXIMITY': {'ID': 'MID', 'DESCRIPTION': 'midway between'}},
#       'TO': {'ID': '',
#        'STREET1': {'ADDRESS1': 'Hallsboro Rd S'},
#        'STREET2': {'ADDRESS1': 'Lake Waccamaw'},
#        'COUNTY': 'Columbus',
#        'STATE': '',
#        'PROXIMITY': {'ID': 'MID', 'DESCRIPTION': 'midway between'}}},
#      'GEOLOC': {'ORIGIN': {'LATITUDE': 34.20031, 'LONGITUDE': -78.60888},
#       'TO': [{'LATITUDE': 34.21948, 'LONGITUDE': -78.6181}],
#       'GEOMETRY': {'SHAPES': {'SHP': [{'value': '34.20031,-78.60888 34.2038,-78.60849 34.20557,-78.60827 34.20651,-78.6081 34.20678,-78.6081 34.20706,-78.60813 34.20782,-78.6083 34.20967,-78.6087 34.21043,-78.60889 34.21067,-78.60897 34.2109,-78.60911 34.2111,-78.6093 34.21148,-78.60971 34.21191,-78.61021',
#           'FC': 5,
#           'LID': '916299493F',
#           'LE': 1.3405062698919392,
#           'FW': 'SD'},
#          {'value': '34.21191,-78.61021 34.21519,-78.61399 34.21737,-78.6165 34.21792,-78.61706 34.21821,-78.61729 34.21879,-78.61766 34.21948,-78.6181',
#           'FC': 5,
#           'LID': '916299494F',
#           'LE': 1.1161877052789806,
#           'FW': 'SD'}]}}},
#      'TPEGOpenLRBase64': 'CCkBEAAlJMgZsRhR+gAJBQQEA/wACgUEBJMZAPxmB30ACQUEBANjADAAAA==',
#      'POLITICAL_BOUNDARY': {'METRO_AREA': {'value': '', 'ID': 65},
#       'COUNTY': 'Columbus'},
#      'NAVTECH': {'EDGE': {'EDGE_ID': ['916299493', '916299494']},
#       'VERSION_ID': '201904'},
#      'LENGTH': 1.52651},
#     'TRAFFIC_ITEM_DETAIL': {'ROAD_CLOSED': True,
#      'EVENT': {'EVENT_ITEM_CANCELLED': False,
#       'SCHEDULED_CONSTRUCTION_EVENT': {'SCHEDULED_CONSTRUCTION_TYPE_DESC': 'CONSTRUCTION',
#        'SCHEDULED_CONSTRUCTION_DETAIL': 'construction'}},
#      'ALERTC': [{'EVENT_CODE': 735}]},
#     'TRAFFIC_ITEM_DESCRIPTION': [{'value': 'Closed between Whiteville and Lake Waccamaw - Closed due to roadwork.',
#       'TYPE': 'short_desc'},
#      {'value': 'Closed between Whiteville and Lake Waccamaw - Closed due to roadwork.',
#       'TYPE': 'desc'},
#      {'value': 'Closed due to roadwork.', 'TYPE': 'no_exit_description'}],
#     'mid': 'NAVTEQ/r_NAVTEQ/11180955_TIC/NAVTEQ_reverse|1573582276018',
#     'PRODUCT': 'basic'},
#    {'TRAFFIC_ITEM_ID': 2974699386547110885,
#     'ORIGINAL_TRAFFIC_ITEM_ID': 729075518661547224,
#     'TRAFFIC_ITEM_STATUS_SHORT_DESC': 'ACTIVE',
#     'TRAFFIC_ITEM_TYPE_DESC': 'ROAD_CLOSURE',
#     'START_TIME': '11/07/2019 18:43:00',
#     'END_TIME': '11/13/2019 22:00:00',
#     'ENTRY_TIME': '11/08/2019 00:29:49',
#     'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#     'VERIFIED': True,
#     'ABBREVIATION': {'SHORT_DESC': 'CLOS', 'DESCRIPTION': ''},
#     'LOCATION': {'INTERSECTION': {'ORIGIN': {'ID': '',
#        'STREET1': {'ADDRESS1': 'Brascote Ln'},
#        'STREET2': {'ADDRESS1': 'Brascote Ln'},
#        'COUNTY': '',
#        'STATE': '',
#        'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#       'TO': {'ID': '',
#        'STREET1': {'ADDRESS1': 'Brascote Ln'},
#        'STREET2': {'ADDRESS1': 'Brascote Ln'},
#        'COUNTY': '',
#        'STATE': '',
#        'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#      'GEOLOC': {'ORIGIN': {'LATITUDE': 34.166602, 'LONGITUDE': -77.900993},
#       'TO': [{'LATITUDE': 34.166602, 'LONGITUDE': -77.900993}],
#       'GEOMETRY': {'SHAPES': {'SHP': [{'value': '34.1649,-77.90112 34.16517,-77.90104 34.16553,-77.90099 34.16665,-77.90099',
#           'FC': 5,
#           'LID': '102772716F',
#           'LE': 0.19527970494192373,
#           'FW': 'SD'}]}}},
#      'TPEGOpenLRBase64': 'CC8BEAIrJsiaiRhLiAAJBQQEAwMACgUEBIFDAAANAK8ACQUEBAOBAAAAQIE+DAIBAA==',
#      'POLITICAL_BOUNDARY': {'METRO_AREA': {'value': '', 'ID': 65}},
#      'NAVTECH': {'EDGE': {'EDGE_ID': ['102772716']}, 'VERSION_ID': '201904'},
#      'LENGTH': 0.0},
#     'TRAFFIC_ITEM_DETAIL': {'ROAD_CLOSED': True,
#      'INCIDENT': {'RESPONSE_VEHICLES': False,
#       'MISCELLANEOUS_INCIDENT': {'MISCELLANEOUS_TYPE_DESC': ''}},
#      'ALERTC': [{'EVENT_CODE': 401}]},
#     'TRAFFIC_ITEM_DESCRIPTION': [{'value': 'Closed at Brascote Ln - Closed.',
#       'TYPE': 'short_desc'},
#      {'value': 'Closed at Brascote Ln - Closed.', 'TYPE': 'desc'},
#      {'value': 'Closed.', 'TYPE': 'no_exit_description'}],
#     'mid': '578555_original|1573172946675',
#     'PRODUCT': 'basic'},
#    {'TRAFFIC_ITEM_ID': 2392104642592698370,
#     'ORIGINAL_TRAFFIC_ITEM_ID': 2392104642592698370,
#     'TRAFFIC_ITEM_STATUS_SHORT_DESC': 'ACTIVE',
#     'TRAFFIC_ITEM_TYPE_DESC': 'CONSTRUCTION',
#     'START_TIME': '10/21/2019 12:00:00',
#     'END_TIME': '03/19/2020 21:00:00',
#     'ENTRY_TIME': '11/07/2019 16:08:52',
#     'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#     'VERIFIED': True,
#     'ABBREVIATION': {'SHORT_DESC': 'CONST', 'DESCRIPTION': 'construction'},
#     'LOCATION': {'INTERSECTION': {'ORIGIN': {'ID': '',
#        'STREET1': {'ADDRESS1': 'Market St Ext'},
#        'STREET2': {'ADDRESS1': 'Market St Ext'},
#        'COUNTY': '',
#        'STATE': '',
#        'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#       'TO': {'ID': '',
#        'STREET1': {'ADDRESS1': 'Market St Ext'},
#        'STREET2': {'ADDRESS1': 'Market St Ext'},
#        'COUNTY': '',
#        'STATE': '',
#        'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#      'GEOLOC': {'ORIGIN': {'LATITUDE': 35.650635, 'LONGITUDE': -77.029274},
#       'TO': [{'LATITUDE': 35.650635, 'LONGITUDE': -77.029274}],
# ...
#     'TRAFFIC_ITEM_DESCRIPTION': [{'value': 'Closed at Melbourne - Closed due to roadwork.',
#       'TYPE': 'short_desc'},
#      {'value': 'Closed at Melbourne - Closed due to roadwork.',
#       'TYPE': 'desc'},
#      {'value': 'Closed due to roadwork.', 'TYPE': 'no_exit_description'}],
#     'mid': '575651_original|1573142883609',
#     'PRODUCT': 'basic'},
#    {'TRAFFIC_ITEM_ID': 2582492514410294528,
#     'ORIGINAL_TRAFFIC_ITEM_ID': 2582492514410294528,
#     'TRAFFIC_ITEM_STATUS_SHORT_DESC': 'ACTIVE',
#     'TRAFFIC_ITEM_TYPE_DESC': 'CONSTRUCTION',
#     'START_TIME': '09/30/2019 13:00:00',
#     'END_TIME': '09/30/2020 16:00:00',
#     'ENTRY_TIME': '11/07/2019 16:08:52',
#     'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#     'VERIFIED': True,
#     'ABBREVIATION': {'SHORT_DESC': 'CONST', 'DESCRIPTION': 'construction'},
#     'LOCATION': {'INTERSECTION': {'ORIGIN': {'ID': '',
#        'STREET1': {'ADDRESS1': 'Melbourne'},
#        'STREET2': {'ADDRESS1': 'Melbourne'},
#        'COUNTY': '',
#        'STATE': '',
#        'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#       'TO': {'ID': '',
#        'STREET1': {'ADDRESS1': 'Melbourne'},
#        'STREET2': {'ADDRESS1': 'Melbourne'},
#        'COUNTY': '',
#        'STATE': '',
#        'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#      'GEOLOC': {'ORIGIN': {'LATITUDE': 35.777027, 'LONGITUDE': -78.709261},
#       'TO': [{'LATITUDE': 35.777027, 'LONGITUDE': -78.709261}],
#       'GEOMETRY': {'SHAPES': {'SHP': [{'value': '35.77672,-78.70876 35.77696,-78.7092 35.77709,-78.70935 35.77735,-78.70981',
#           'FC': 5,
#           'LID': '118991077F',
#           'LE': 0.11828916733617106,
#           'FW': 'SD'}]}}},
#      'TPEGOpenLRBase64': 'CC0BEAIpJMgHghlw9AAJBQQEA9oACgQDBHYA/5cAPwAJBQQEA1oAAABAOQwCAQA=',
#      'POLITICAL_BOUNDARY': {'METRO_AREA': {'value': '', 'ID': 65}},
#      'NAVTECH': {'EDGE': {'EDGE_ID': ['118991077']}, 'VERSION_ID': '201904'},
#      'LENGTH': 0.0},
#     'TRAFFIC_ITEM_DETAIL': {'ROAD_CLOSED': True,
#      'EVENT': {'EVENT_ITEM_CANCELLED': False,
#       'SCHEDULED_CONSTRUCTION_EVENT': {'SCHEDULED_CONSTRUCTION_TYPE_DESC': 'CONSTRUCTION',
#        'SCHEDULED_CONSTRUCTION_DETAIL': 'construction'}},
#      'ALERTC': [{'EVENT_CODE': 735}]},
#     'TRAFFIC_ITEM_DESCRIPTION': [{'value': 'Closed at Melbourne - Closed due to roadwork.',
#       'TYPE': 'short_desc'},
#      {'value': 'Closed at Melbourne - Closed due to roadwork.',
#       'TYPE': 'desc'},
#      {'value': 'Closed due to roadwork.', 'TYPE': 'no_exit_description'}],
#     'mid': '575651_reverse|1573142883609',
#     'PRODUCT': 'basic'},
#    {'TRAFFIC_ITEM_ID': 602359011455195827,
#     'ORIGINAL_TRAFFIC_ITEM_ID': 602359011455195827,
#     'TRAFFIC_ITEM_STATUS_SHORT_DESC': 'ACTIVE',
#     'TRAFFIC_ITEM_TYPE_DESC': 'CONSTRUCTION',
#     'START_TIME': '11/12/2019 13:00:00',
#     'END_TIME': '11/14/2019 22:00:00',
#     'ENTRY_TIME': '11/11/2019 13:00:34',
#     'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#     'VERIFIED': True,
#     'ABBREVIATION': {'SHORT_DESC': 'CONST', 'DESCRIPTION': 'construction'},
#     'LOCATION': {'INTERSECTION': {'ORIGIN': {'ID': '',
#        'STREET1': {'ADDRESS1': 'Rockford Church Rd'},
#        'STREET2': {'ADDRESS1': 'Rockford Church Rd'},
#        'COUNTY': '',
#        'STATE': '',
#        'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#       'TO': {'ID': '',
#        'STREET1': {'ADDRESS1': 'Rockford Church Rd'},
#        'STREET2': {'ADDRESS1': 'Rockford Church Rd'},
#        'COUNTY': '',
#        'STATE': '',
#        'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#      'GEOLOC': {'ORIGIN': {'LATITUDE': 35.234038, 'LONGITUDE': -77.826608},
#       'TO': [{'LATITUDE': 35.234038, 'LONGITUDE': -77.826608}],
#       'GEOMETRY': {'SHAPES': {'SHP': [{'value': '35.2348,-77.83078 35.23468,-77.83023 35.23443,-77.82891 35.23424,-77.82783 35.23401,-77.82651 35.23393,-77.82591 35.23387,-77.82508 35.23385,-77.824 35.23382,-77.82142 35.23381,-77.82111 35.23377,-77.82073 35.23371,-77.82046',
#           'FC': 5,
#           'LID': '102875789T',
#           'LE': 0.9514663986918039,
#           'FW': 'SD'}]}}},
#      'TPEGOpenLRBase64': 'CC8BEAIrJsimPBkOnAAJBQQEA04ACgUEBIt+AAZm/ukACQUEBAPFAAAAQIdLDAIBAA==',
#      'POLITICAL_BOUNDARY': {'METRO_AREA': {'value': '', 'ID': 65}},
#      'NAVTECH': {'EDGE': {'EDGE_ID': ['102875789']}, 'VERSION_ID': '201904'},
#      'LENGTH': 0.0},
#     'TRAFFIC_ITEM_DETAIL': {'ROAD_CLOSED': True,
#      'EVENT': {'EVENT_ITEM_CANCELLED': False,
#       'SCHEDULED_CONSTRUCTION_EVENT': {'SCHEDULED_CONSTRUCTION_TYPE_DESC': 'CONSTRUCTION',
#        'SCHEDULED_CONSTRUCTION_DETAIL': 'construction'}},
#      'ALERTC': [{'EVENT_CODE': 735}]},
#     'TRAFFIC_ITEM_DESCRIPTION': [{'value': 'Closed at Rockford Church Rd - Closed due to roadwork.',
#       'TYPE': 'short_desc'},
#      {'value': 'Closed at Rockford Church Rd - Closed due to roadwork.',
#       'TYPE': 'desc'},
#      {'value': 'Closed due to roadwork.', 'TYPE': 'no_exit_description'}],
#     'mid': '578474_reverse|1573477210941',
#     'PRODUCT': 'basic'},
#    {'TRAFFIC_ITEM_ID': 355123321898274420,
#     'ORIGINAL_TRAFFIC_ITEM_ID': 146756180338198429,
#     'TRAFFIC_ITEM_STATUS_SHORT_DESC': 'ACTIVE',
#     'TRAFFIC_ITEM_TYPE_DESC': 'CONSTRUCTION',
#     'START_TIME': '04/29/2019 13:18:00',
#     'END_TIME': '11/02/2020 04:59:00',
#     'ENTRY_TIME': '11/08/2019 00:29:49',
#     'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#     'VERIFIED': True,
#     'ABBREVIATION': {'SHORT_DESC': 'CONST', 'DESCRIPTION': 'construction'},
#     'RDS-TMC_LOCATIONS': {'RDS-TMC': [{'ORIGIN': {'EBU_COUNTRY_CODE': '1',
#         'TABLE_ID': 25,
#         'LOCATION_ID': '18088',
#         'LOCATION_DESC': 'US-17/US-421',
#         'RDS_DIRECTION': '+'},
#        'DIRECTION': '-',
#        'ALERTC': {'TRAFFIC_CODE': 735,
#         'QUANTIFIERS': 0,
#         'DESCRIPTION': 'Closed due to roadwork.',
#         'ALERTC_DURATION': 'L',
#         'ALERTC_DIRECTION': 1,
#         'URGENCY': 'U',
#         'UPDATE_CLASS': 5,
#         'PHRASE_CODE': 'E1.C1',
#         'EXTENT': '1',
#         'DURATION': 0},
#        'LENGTH': 0.01398,
#        'PRIMARY_OFFSET': 0.36288},
#       {'ORIGIN': {'EBU_COUNTRY_CODE': '1',
#         'TABLE_ID': 25,
#         'LOCATION_ID': '18088',
#         'LOCATION_DESC': 'US-17/US-421',
#         'RDS_DIRECTION': '+'},
#        'DIRECTION': '-',
#        'ALERTC': {'TRAFFIC_CODE': 641,
#         'DESCRIPTION': 'One lane closed.',
#         'ALERTC_DURATION': 'L',
#         'ALERTC_DIRECTION': 1,
#         'UPDATE_CLASS': 5,
#         'PHRASE_CODE': 'D24',
#         'EXTENT': '1',
#         'DURATION': 0},
#        'LENGTH': 0.01398,
#        'PRIMARY_OFFSET': 0.36288}]},
#     'LOCATION': {'DEFINED': {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'value': 'US-74',
#           'TYPE': 'NTCSA'},
#          {'value': 'US-74', 'TYPE': 'RDSGN'},
#          {'value': 'US-74', 'TYPE': 'LOCAL'}],
#         'ID': 18087},
#        'POINT': {'DESCRIPTION': [{'value': 'N 3rd St', 'TYPE': 'NTCSA'},
#          {'value': 'N 3rd St', 'TYPE': 'RDSGN'},
#          {'value': 'N 3rd St', 'TYPE': 'LOCAL'},
#          {'value': 'US-74', 'TYPE': 'BNAME'}],
#         'ID': 18088},
#        'DIRECTION': {'DESCRIPTION': [{'value': 'WESTBOUND', 'TYPE': 'LOCAL'},
#          {'value': 'WESTBOUND', 'TYPE': 'NTCSA'},
#          {'value': 'WESTBOUND', 'TYPE': 'RDSGN'}],
#         'ID': 0},
#        'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#       'TO': {'ROADWAY': {'DESCRIPTION': [{'value': 'US-74', 'TYPE': 'NTCSA'},
#          {'value': 'US-74', 'TYPE': 'RDSGN'},
#          {'value': 'US-74', 'TYPE': 'LOCAL'}],
#         'ID': 18087},
#        'POINT': {'DESCRIPTION': [{'value': 'US-17/US-421', 'TYPE': 'NTCSA'},
#          {'value': 'US-17/US-421', 'TYPE': 'RDSGN'},
#          {'value': 'US-17/US-421', 'TYPE': 'LOCAL'},
#          {'value': 'US-74', 'TYPE': 'BNAME'}],
#         'ID': 18088},
#        'DIRECTION': {'DESCRIPTION': [{'value': 'WESTBOUND', 'TYPE': 'LOCAL'},
#          {'value': 'WESTBOUND', 'TYPE': 'NTCSA'},
#          {'value': 'WESTBOUND', 'TYPE': 'RDSGN'}],
#         'ID': 0},
#        'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#      'GEOLOC': {'ORIGIN': {'LATITUDE': 34.25204, 'LONGITUDE': -77.95092},
#       'TO': [{'LATITUDE': 34.25214, 'LONGITUDE': -77.95112}]},
#      'TPEGOpenLRBase64': 'CCoBEAAmJciRohhbUQAJBQQDA9UACgUEA4U8AP00AEYACQUEAwNBADAAg0w=',
#      'NAVTECH': {'EDGE': {'EDGE_ID': ['135922182', '1070870404']},
#       'VERSION_ID': '201904'},
#      'LENGTH': 0.01398},
#     'TRAFFIC_ITEM_DETAIL': {'ROAD_CLOSED': True,
#      'EVENT': {'EVENT_ITEM_CANCELLED': False,
#       'SCHEDULED_CONSTRUCTION_EVENT': {'SCHEDULED_CONSTRUCTION_TYPE_DESC': 'CONSTRUCTION',
#        'SCHEDULED_CONSTRUCTION_DETAIL': 'construction'}},
#      'ALERTC': [{'EVENT_CODE': 735}, {'EVENT_CODE': 641}]},
#     'TRAFFIC_ITEM_DESCRIPTION': [{'value': 'Closed at US-17/US-421 - Closed due to roadwork. One lane closed.',
#       'TYPE': 'short_desc'},
#      {'value': 'Closed at US-17/US-421 - Closed due to roadwork. One lane closed.',
#       'TYPE': 'desc'},
#      {'value': 'Closed due to roadwork. One lane closed.',
#       'TYPE': 'no_exit_description'}],
#     'mid': 'b6b3e372-dc83-4df9-858f-7332433a9ec0|1573172989396',
#     'PRODUCT': 'basic'},
#    {'TRAFFIC_ITEM_ID': 3847906998429882112,
#     'ORIGINAL_TRAFFIC_ITEM_ID': 2331383106973665066,
#     'TRAFFIC_ITEM_STATUS_SHORT_DESC': 'ACTIVE',
#     'TRAFFIC_ITEM_TYPE_DESC': 'CONSTRUCTION',
#     'START_TIME': '05/28/2019 11:32:00',
#     'END_TIME': '05/13/2020 11:32:00',
#     'ENTRY_TIME': '11/08/2019 00:29:49',
#     'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#     'VERIFIED': True,
#     'ABBREVIATION': {'SHORT_DESC': 'CONST', 'DESCRIPTION': 'construction'},
#     'LOCATION': {'INTERSECTION': {'ORIGIN': {'ID': '',
#        'STREET1': {'ADDRESS1': 'East Modlin Road'},
#        'STREET2': {'ADDRESS1': 'East Modlin Road'},
#        'COUNTY': '',
#        'STATE': '',
#        'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#       'TO': {'ID': '',
#        'STREET1': {'ADDRESS1': 'East Modlin Road'},
#        'STREET2': {'ADDRESS1': 'East Modlin Road'},
#        'COUNTY': '',
#        'STATE': '',
#        'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#      'GEOLOC': {'ORIGIN': {'LATITUDE': 36.320277, 'LONGITUDE': -77.002846},
#       'TO': [{'LATITUDE': 36.320277, 'LONGITUDE': -77.002846}],
#       'GEOMETRY': {'SHAPES': {'SHP': [{'value': '36.32149,-77.00642 36.32023,-77.00272',
#           'FC': 5,
#           'LID': '90910931T',
#           'LE': 0.36046924600883334,
#           'FW': 'SD'}]}}},
#      'TPEGOpenLRBase64': 'CC8BEAIrJsk9aRnUIAAJBQQEA1AACgUEBIJoAAFx/4IACQUEBAPQAAAAQIJbDAIBAA==',
#      'POLITICAL_BOUNDARY': {'METRO_AREA': {'value': '', 'ID': 61}},
#      'NAVTECH': {'EDGE': {'EDGE_ID': ['90910931']}, 'VERSION_ID': '201904'},
#      'LENGTH': 0.0},
#     'TRAFFIC_ITEM_DETAIL': {'ROAD_CLOSED': True,
#      'EVENT': {'EVENT_ITEM_CANCELLED': False,
#       'SCHEDULED_CONSTRUCTION_EVENT': {'SCHEDULED_CONSTRUCTION_TYPE_DESC': 'CONSTRUCTION',
#        'SCHEDULED_CONSTRUCTION_DETAIL': 'construction'}},
#      'ALERTC': [{'EVENT_CODE': 735}]},
#     'TRAFFIC_ITEM_DESCRIPTION': [{'value': 'Closed at East Modlin Road - Closed due to roadwork.',
#       'TYPE': 'short_desc'},
#      {'value': 'Closed at East Modlin Road - Closed due to roadwork.',
#       'TYPE': 'desc'},
#      {'value': 'Closed due to roadwork.', 'TYPE': 'no_exit_description'}],
#     'mid': '566119_original|1573172946675',
#     'PRODUCT': 'basic'},
#    {'TRAFFIC_ITEM_ID': 1098508981182454983,
#     'ORIGINAL_TRAFFIC_ITEM_ID': 1098508981182454983,
#     'TRAFFIC_ITEM_STATUS_SHORT_DESC': 'ACTIVE',
#     'TRAFFIC_ITEM_TYPE_DESC': 'CONSTRUCTION',
#     'START_TIME': '11/12/2019 13:00:00',
#     'END_TIME': '11/14/2019 22:00:00',
#     'ENTRY_TIME': '11/11/2019 13:00:34',
#     'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#     'VERIFIED': True,
#     'ABBREVIATION': {'SHORT_DESC': 'CONST', 'DESCRIPTION': 'construction'},
#     'LOCATION': {'INTERSECTION': {'ORIGIN': {'ID': '',
#        'STREET1': {'ADDRESS1': 'Rockford Church Rd'},
#        'STREET2': {'ADDRESS1': 'Rockford Church Rd'},
#        'COUNTY': '',
#        'STATE': '',
#        'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#       'TO': {'ID': '',
#        'STREET1': {'ADDRESS1': 'Rockford Church Rd'},
#        'STREET2': {'ADDRESS1': 'Rockford Church Rd'},
#        'COUNTY': '',
#        'STATE': '',
#        'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#      'GEOLOC': {'ORIGIN': {'LATITUDE': 35.234038, 'LONGITUDE': -77.826608},
#       'TO': [{'LATITUDE': 35.234038, 'LONGITUDE': -77.826608}],
#       'GEOMETRY': {'SHAPES': {'SHP': [{'value': '35.23371,-77.82046 35.23377,-77.82073 35.23381,-77.82111 35.23382,-77.82142 35.23385,-77.824 35.23387,-77.82508 35.23393,-77.82591 35.23401,-77.82651 35.23424,-77.82783 35.23443,-77.82891 35.23468,-77.83023 35.2348,-77.83078',
#           'FC': 5,
#           'LID': '102875789F',
#           'LE': 0.9514663986918039,
#           'FW': 'SD'}]}}},
#      'TPEGOpenLRBase64': 'CC8BEAIrJsipOBkOGgAJBQQEA8UACgUEBIt+APmaARcACQUEBANOAAAAQIQxDAIBAA==',
#      'POLITICAL_BOUNDARY': {'METRO_AREA': {'value': '', 'ID': 65}},
#      'NAVTECH': {'EDGE': {'EDGE_ID': ['102875789']}, 'VERSION_ID': '201904'},
#      'LENGTH': 0.0},
#     'TRAFFIC_ITEM_DETAIL': {'ROAD_CLOSED': True,
#      'EVENT': {'EVENT_ITEM_CANCELLED': False,
#       'SCHEDULED_CONSTRUCTION_EVENT': {'SCHEDULED_CONSTRUCTION_TYPE_DESC': 'CONSTRUCTION',
#        'SCHEDULED_CONSTRUCTION_DETAIL': 'construction'}},
#      'ALERTC': [{'EVENT_CODE': 735}]},
#     'TRAFFIC_ITEM_DESCRIPTION': [{'value': 'Closed at Rockford Church Rd - Closed due to roadwork.',
#       'TYPE': 'short_desc'},
#      {'value': 'Closed at Rockford Church Rd - Closed due to roadwork.',
#       'TYPE': 'desc'},
#      {'value': 'Closed due to roadwork.', 'TYPE': 'no_exit_description'}],
#     'mid': '578474_original|1573477210941',
#     'PRODUCT': 'basic'},
#    {'TRAFFIC_ITEM_ID': 286382561666434839,
#     'ORIGINAL_TRAFFIC_ITEM_ID': 532024019821489193,
#     'TRAFFIC_ITEM_STATUS_SHORT_DESC': 'ACTIVE',
#     'TRAFFIC_ITEM_TYPE_DESC': 'CONSTRUCTION',
#     'START_TIME': '09/16/2019 11:00:00',
#     'END_TIME': '06/24/2020 21:00:00',
#     'ENTRY_TIME': '11/08/2019 00:29:49',
#     'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#     'VERIFIED': True,
#     'ABBREVIATION': {'SHORT_DESC': 'CONST', 'DESCRIPTION': 'construction'},
#     'LOCATION': {'INTERSECTION': {'ORIGIN': {'ID': '',
#        'STREET1': {'ADDRESS1': 'NC Hwy 41'},
#        'STREET2': {'ADDRESS1': 'NC Hwy 41'},
#        'COUNTY': '',
#        'STATE': '',
#        'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#       'TO': {'ID': '',
#        'STREET1': {'ADDRESS1': 'NC Hwy 41'},
#        'STREET2': {'ADDRESS1': 'NC Hwy 41'},
#        'COUNTY': '',
#        'STATE': '',
#        'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#      'GEOLOC': {'ORIGIN': {'LATITUDE': 34.643348, 'LONGITUDE': -78.735957},
#       'TO': [{'LATITUDE': 34.643348, 'LONGITUDE': -78.735957}],
#       'GEOMETRY': {'SHAPES': {'SHP': [{'value': '34.64335,-78.73596 34.64305,-78.73612',
#           'FC': 4,
#           'LID': '1228561539T',
#           'LE': 0.03636965587275184,
#           'FW': 'SD'}]}}},
#      'TPEGOpenLRBase64': 'CC4BEAIqJcgCjhiioQAJBQQDA5EACgUEA4gEAP4a/L0ACQUEAwMSAAAAQAAMAgEA',
#      'POLITICAL_BOUNDARY': {'METRO_AREA': {'value': '', 'ID': 65}},
#      'NAVTECH': {'EDGE': {'EDGE_ID': ['1228561539']}, 'VERSION_ID': '201904'},
#      'LENGTH': 0.0},
#     'TRAFFIC_ITEM_DETAIL': {'ROAD_CLOSED': True,
#      'EVENT': {'EVENT_ITEM_CANCELLED': False,
#       'SCHEDULED_CONSTRUCTION_EVENT': {'SCHEDULED_CONSTRUCTION_TYPE_DESC': 'CONSTRUCTION',
#        'SCHEDULED_CONSTRUCTION_DETAIL': 'construction'}},
#      'ALERTC': [{'EVENT_CODE': 735}]},
#     'TRAFFIC_ITEM_DESCRIPTION': [{'value': 'Closed at NC Hwy 41 - Closed due to roadwork.',
#       'TYPE': 'short_desc'},
#      {'value': 'Closed at NC Hwy 41 - Closed due to roadwork.',
#       'TYPE': 'desc'},
#      {'value': 'Closed due to roadwork.', 'TYPE': 'no_exit_description'}],
#     'mid': '574662_reverse|1573172946675',
#     'PRODUCT': 'basic'}]},
#  'diagnostic': {'info': '',
#   'sfile': 'Incident-A0110-1573585678540.xml.gz',
#   'pdd': 'trafficml-incident-24-v259'},
#  'TIMESTAMP2': '2019-11-12T19:07:58.000+0000',
#  'EXTENDED_COUNTRY_CODE': 'A0'}

# %%
# Code used from DSI-DC (2)
incidents = pd.DataFrame(hmaps_json['TRAFFIC_ITEMS']['TRAFFIC_ITEM'])

# %%
incidents = incidents.drop(axis=1, columns=['ABBREVIATION', 'ORIGINAL_TRAFFIC_ITEM_ID', 'PRODUCT',
                                              'TRAFFIC_ITEM_ID', 'mid'])
incidents.rename(str.lower, axis=1, inplace=True)

# %%
# Display new dataframe with location information
incidents
# Out:
#     traffic_item_status_short_desc traffic_item_type_desc  \
# 0                           ACTIVE           ROAD_CLOSURE
# 1                           ACTIVE          MISCELLANEOUS
# 2                           ACTIVE           CONSTRUCTION
# 3                           ACTIVE           CONSTRUCTION
# 4                           ACTIVE           CONSTRUCTION
# ..                             ...                    ...
# 99                          ACTIVE           CONSTRUCTION
# 100                         ACTIVE           CONSTRUCTION
# 101                         ACTIVE           CONSTRUCTION
# 102                         ACTIVE           CONSTRUCTION
# 103                         ACTIVE           CONSTRUCTION
#
#               start_time             end_time           entry_time  \
# 0    06/10/2019 19:24:00  07/01/2020 00:00:00  11/07/2019 16:08:52
# 1    11/07/2019 16:10:21  07/23/2020 03:59:00  11/07/2019 16:10:21
# 2    07/08/2019 14:54:00  11/20/2019 16:54:00  11/07/2019 16:08:52
# 3    10/28/2019 11:00:00  11/15/2019 21:00:00  11/07/2019 16:08:52
# 4    06/17/2019 14:00:00  12/14/2019 16:00:00  11/08/2019 00:29:49
# ..                   ...                  ...                  ...
# 99   11/12/2019 13:00:00  11/14/2019 22:00:00  11/11/2019 13:00:34
# 100  04/29/2019 13:18:00  11/02/2020 04:59:00  11/08/2019 00:29:49
# 101  05/28/2019 11:32:00  05/13/2020 11:32:00  11/08/2019 00:29:49
# 102  11/12/2019 13:00:00  11/14/2019 22:00:00  11/11/2019 13:00:34
# 103  09/16/2019 11:00:00  06/24/2020 21:00:00  11/08/2019 00:29:49
#
#                                 criticality  verified  \
# 0    {'ID': '0', 'DESCRIPTION': 'critical'}      True
# 1    {'ID': '0', 'DESCRIPTION': 'critical'}      True
# 2    {'ID': '0', 'DESCRIPTION': 'critical'}      True
# 3    {'ID': '0', 'DESCRIPTION': 'critical'}      True
# 4    {'ID': '0', 'DESCRIPTION': 'critical'}      True
# ..                                      ...       ...
# 99   {'ID': '0', 'DESCRIPTION': 'critical'}      True
# 100  {'ID': '0', 'DESCRIPTION': 'critical'}      True
# 101  {'ID': '0', 'DESCRIPTION': 'critical'}      True
# 102  {'ID': '0', 'DESCRIPTION': 'critical'}      True
# 103  {'ID': '0', 'DESCRIPTION': 'critical'}      True
#
#                                               location  \
# 0    {'INTERSECTION': {'ORIGIN': {'ID': '', 'STREET...
# 1    {'INTERSECTION': {'ORIGIN': {'ID': '', 'STREET...
# 2    {'INTERSECTION': {'ORIGIN': {'ID': '', 'STREET...
# 3    {'INTERSECTION': {'ORIGIN': {'ID': '', 'STREET...
# 4    {'DEFINED': {'ORIGIN': {'ROADWAY': {'DESCRIPTI...
# ..                                                 ...
# 99   {'INTERSECTION': {'ORIGIN': {'ID': '', 'STREET...
# 100  {'DEFINED': {'ORIGIN': {'ROADWAY': {'DESCRIPTI...
# 101  {'INTERSECTION': {'ORIGIN': {'ID': '', 'STREET...
# 102  {'INTERSECTION': {'ORIGIN': {'ID': '', 'STREET...
# 103  {'INTERSECTION': {'ORIGIN': {'ID': '', 'STREET...
#
#                                    traffic_item_detail  \
# 0    {'ROAD_CLOSED': True, 'INCIDENT': {'RESPONSE_V...
# 1    {'ROAD_CLOSED': True, 'INCIDENT': {'RESPONSE_V...
# 2    {'ROAD_CLOSED': True, 'EVENT': {'EVENT_ITEM_CA...
# 3    {'ROAD_CLOSED': True, 'EVENT': {'EVENT_ITEM_CA...
# 4    {'ROAD_CLOSED': True, 'EVENT': {'EVENT_ITEM_CA...
# ..                                                 ...
# 99   {'ROAD_CLOSED': True, 'EVENT': {'EVENT_ITEM_CA...
# 100  {'ROAD_CLOSED': True, 'EVENT': {'EVENT_ITEM_CA...
# 101  {'ROAD_CLOSED': True, 'EVENT': {'EVENT_ITEM_CA...
# 102  {'ROAD_CLOSED': True, 'EVENT': {'EVENT_ITEM_CA...
# 103  {'ROAD_CLOSED': True, 'EVENT': {'EVENT_ITEM_CA...
#
#                               traffic_item_description  \
# 0    [{'value': 'Closed at Country Club Rd - Closed...
# 1    [{'value': 'Closed between Pine Level and Poll...
# 2    [{'value': 'Closed at Pearces Rd. - Closed due...
# 3    [{'value': 'Closed at Neuse Rd - Closed due to...
# 4    [{'value': 'Closed at US-701 - Closed due to r...
# ..                                                 ...
# 99   [{'value': 'Closed at Rockford Church Rd - Clo...
# 100  [{'value': 'Closed at US-17/US-421 - Closed du...
# 101  [{'value': 'Closed at East Modlin Road - Close...
# 102  [{'value': 'Closed at Rockford Church Rd - Clo...
# 103  [{'value': 'Closed at NC Hwy 41 - Closed due t...
#
#                                      rds-tmc_locations
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    {'RDS-TMC': [{'ORIGIN': {'EBU_COUNTRY_CODE': '...
# ..                                                 ...
# 99                                                 NaN
# 100  {'RDS-TMC': [{'ORIGIN': {'EBU_COUNTRY_CODE': '...
# 101                                                NaN
# 102                                                NaN
# 103                                                NaN
#
# [104 rows x 11 columns]

# %%
# Create a dataframe for all location information
locations = pd.DataFrame(list(incidents['location']))
locations.rename(str.lower, axis=1, inplace=True)

# %%
# Fill NaN Values with empty dictionaries so that dataframes can continue to be created
locations = locations.applymap(lambda x: {} if pd.isnull(x) else x)

# %%
loc_region = pd.DataFrame(list(locations['political_boundary']))
loc_region.rename(str.lower, axis=1, inplace=True)

# %%
#Create a dataframe for only intersections. NaNs indicate no value was provided by HereMaps.\n",
loc_intersec = pd.DataFrame(list(locations['intersection']))
loc_intersec.rename(str.lower, axis=1, inplace=True)
loc_intersec.head()
# Out:
#                                               origin  \
# 0  {'ID': '', 'STREET1': {'ADDRESS1': 'Country Cl...
# 1  {'ID': '', 'STREET1': {'ADDRESS1': 'Selma'}, '...
# 2  {'ID': '', 'STREET1': {'ADDRESS1': 'Pearces Rd...
# 3  {'ID': '', 'STREET1': {'ADDRESS1': 'Neuse Rd'}...
# 4                                                NaN
#
#                                                   to
# 0  {'ID': '', 'STREET1': {'ADDRESS1': 'Country Cl...
# 1  {'ID': '', 'STREET1': {'ADDRESS1': 'Selma'}, '...
# 2  {'ID': '', 'STREET1': {'ADDRESS1': 'Pearces Rd...
# 3  {'ID': '', 'STREET1': {'ADDRESS1': 'Neuse Rd'}...
# 4                                                NaN

# %%
# Create a dataframe for the start/end points of each incident. 
# geocoordinates will eventually feed into our mapping tool,
loc_coord = pd.DataFrame(list(locations['geoloc']))
loc_coord.rename(str.lower, axis=1, inplace=True)
loc_coord.head()
# Out:
#                                              origin  \
# 0  {'LATITUDE': 35.895263, 'LONGITUDE': -78.319615}
# 1     {'LATITUDE': 35.53995, 'LONGITUDE': -78.2418}
# 2  {'LATITUDE': 35.933946, 'LONGITUDE': -78.296641}
# 3  {'LATITUDE': 35.119702, 'LONGITUDE': -76.891707}
# 4    {'LATITUDE': 34.74355, 'LONGITUDE': -78.40795}
#
#                                                   to  \
# 0  [{'LATITUDE': 35.895263, 'LONGITUDE': -78.3196...
# 1   [{'LATITUDE': 35.54067, 'LONGITUDE': -78.24568}]
# 2  [{'LATITUDE': 35.933946, 'LONGITUDE': -78.2966...
# 3  [{'LATITUDE': 35.119702, 'LONGITUDE': -76.8917...
# 4   [{'LATITUDE': 34.74355, 'LONGITUDE': -78.40795}]
#
#                                             geometry
# 0  {'SHAPES': {'SHP': [{'value': '35.89247,-78.32...
# 1  {'SHAPES': {'SHP': [{'value': '35.53995,-78.24...
# 2  {'SHAPES': {'SHP': [{'value': '35.93038,-78.29...
# 3  {'SHAPES': {'SHP': [{'value': '35.11931,-76.89...
# 4                                                NaN

# %%
#Break apart the lat and lon coordinates in the origin column 
origin = loc_coord['origin'].apply(pd.Series)
origin.head()
# Out:
#     LATITUDE  LONGITUDE
# 0  35.895263 -78.319615
# 1  35.539950 -78.241800
# 2  35.933946 -78.296641
# 3  35.119702 -76.891707
# 4  34.743550 -78.407950

# %%
# Add a start_end column and create an incident column thats the index 
# For Start
origin['start_end'] = 'start'
origin['incident'] = origin.index
origin.head()
# Out:
#     LATITUDE  LONGITUDE start_end  incident
# 0  35.895263 -78.319615     start         0
# 1  35.539950 -78.241800     start         1
# 2  35.933946 -78.296641     start         2
# 3  35.119702 -76.891707     start         3
# 4  34.743550 -78.407950     start         4

# %%
# Break apart lat and long
to = pd.DataFrame(s for k, v in loc_coord['to'].items() for s in v)

# %%
# Add a start_end column and create an incident column thats the index 
# For End

to['start_end'] = 'end'
to['incident'] = to.index
to.head()
# Out:
#     LATITUDE  LONGITUDE start_end  incident
# 0  35.895263 -78.319615       end         0
# 1  35.540670 -78.245680       end         1
# 2  35.933946 -78.296641       end         2
# 3  35.119702 -76.891707       end         3
# 4  34.743550 -78.407950       end         4

# %%
#concat the origin and to dfs 
all_locations = pd.concat((origin, to), axis=0)
all_locations.shape
# Out:
# (208, 4)

# %%
# Export and save to csv
all_locations.to_csv('here_locations.csv', index= False)

# %% [markdown]
# ### SUMMARY

# %% [markdown]
# - Final result will turn a json dictionary that here.com returns into a dataframe with latitude and longitude coordinates. These coordinates will be used to map and create routes through our app.
