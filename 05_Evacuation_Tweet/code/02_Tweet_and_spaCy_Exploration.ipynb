# %% [markdown]
# # Tweet and spaCy EDA
# This notebook looks at the capabilities of spaCy in extracting location in formation from our live tweets.

# %%
import jsonpickle
import json
import datetime
import time

import regex as re
import pandas as pd
import spacy

# %%
live_tweets = pd.read_csv('../data/tweets/current_tweets.csv')

# %%
live_tweets.head()
# Out:
#                     id       username                       date  \
# 0  1194676579634470912  CaltransDist6  2019-11-13 18:01:07+00:00
# 1  1194417493013516288  CaltransDist6  2019-11-13 00:51:36+00:00
# 2  1194299055335194624  CaltransDist6  2019-11-12 17:00:58+00:00
# 3  1194169567175532544  CaltransDist6  2019-11-12 08:26:26+00:00
# 4  1194142636254171136  CaltransDist6  2019-11-12 06:39:25+00:00
#
#                                                 text hashtags  geo      type
# 0  Notice a bad pothole or litter? Report Califor...      NaN  NaN  official
# 1  EAST MADERA COUNTY/OAKHURST AREA: Caltrans cre...      NaN  NaN  official
# 2  Caltrans' Volunteer Program can assist in fulf...      NaN  NaN  official
# 3  FRESNO: Eastbound 180 NOW OPEN at 41 following...      NaN  NaN  official
# 4  FRESNO: Eastbound 180 CLOSED at 41 due to acci...      NaN  NaN  official

# %%
nlp = spacy.load("en_core_web_sm")

# %%
live_tweets[live_tweets['username']=="CaltransDist6"]['text']
# Out:
# 0      Notice a bad pothole or litter? Report Califor...
# 1      EAST MADERA COUNTY/OAKHURST AREA: Caltrans cre...
# 2      Caltrans' Volunteer Program can assist in fulf...
# 3      FRESNO: Eastbound 180 NOW OPEN at 41 following...
# 4      FRESNO: Eastbound 180 CLOSED at 41 due to acci...
#                              ...
# 195    CITY OF FRESNO: Tonight, Monday, June 24 from ...
# 196    CITY OF FRESNO: Southbound State Route 99 nort...
# 197    KERN COUNTY: The big rig has been cleared from...
# 198    KERN COUNTY: Traffic is currently backed up on...
# 199    TULARE COUNTY:State Route 137 between Rd 44 an...
# Name: text, Length: 200, dtype: object

# %% [markdown]
# # Training spaCy
# Training spaCy is an extensive process. It is possible to add known entities to its basic vocabulary. To do this, we scraped every street name in California, but the syntax for appending those terms to the spaCy library was beyond what our time allowed.
#
# In future iterations, we would either need to build up this process to create a robust library of street names, interstates, state routes, exits and cross-streets for whatever region we are looking at, or we would need to find a workaround that did not rely on spaCy.

# %%
# spaCy with its basic english package, is able to recognize locations like 
# "California" and "Asia" it was unable to pull streenames for us.
doc = nlp(live_tweets['text'][1])

spacy.displacy.render(doc, style='ent', jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     EAST MADERA COUNTY
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# /OAKHURST AREA:
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Caltrans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  crews will be working on State Route 41 between
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     State Route 145
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Avenue 15
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . Work will begin
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     tomorrow, Wednesday, November 13
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and is scheduled to end on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Friday, November 15
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . Southbound traffic will be placed on a signed detour.pic.twitter.com/dwodudLrrS</div>

# %%
streets = pd.read_csv('../data/scrapes/california_street_names.csv')

# %% [markdown]
# ## spaCy training example from website.
# Example of training spaCy's named entity recognizer, starting off with an
# existing model or a blank model.
#
# For more details, see the documentation:
# * Training: https://spacy.io/usage/training
# * NER: https://spacy.io/usage/linguistic-features#named-entities
#
# Compatible with: spaCy v2.0.0+
# Last tested with: v2.1.0
# """
#
# ```python
# from __future__ import unicode_literals, print_function
#
# import plac
# import random
# from pathlib import Path
# import spacy
# from spacy.util import minibatch, compounding
#
# TRAIN_DATA = listo
#
# @plac.annotations(
#     model=("Model name. Defaults to blank 'en' model.", "option", "m", str),
#     output_dir=("Optional output directory", "option", "o", Path),
#     n_iter=("Number of training iterations", "option", "n", int),
# )
# def main(model=None, output_dir=None, n_iter=100):
#     """Load the model, set up the pipeline and train the entity recognizer."""
#     if model is not None:
#         nlp = spacy.load(model)  # load existing spaCy model
#         print("Loaded model '%s'" % model)
#     else:
#         nlp = spacy.blank("en")  # create blank Language class
#         print("Created blank 'en' model")
#
#     # create the built-in pipeline components and add them to the pipeline
#     # nlp.create_pipe works for built-ins that are registered with spaCy
#     if "ner" not in nlp.pipe_names:
#         ner = nlp.create_pipe("ner")
#         nlp.add_pipe(ner, last=True)
#     # otherwise, get it so we can add labels
#     else:
#         ner = nlp.get_pipe("ner")
#
#     # add labels
#     for _, annotations in TRAIN_DATA:
#         for ent in annotations.get("entities"):
#             ner.add_label(ent[2])
#
#     # get names of other pipes to disable them during training
#     other_pipes = [pipe for pipe in nlp.pipe_names if pipe != "ner"]
#     with nlp.disable_pipes(*other_pipes):  # only train NER
#         # reset and initialize the weights randomly – but only if we're
#         # training a new model
#         if model is None:
#             nlp.begin_training()
#         for itn in range(n_iter):
#             random.shuffle(TRAIN_DATA)
#             losses = {}
#             # batch up the examples using spaCy's minibatch
#             batches = minibatch(TRAIN_DATA, size=compounding(4.0, 32.0, 1.001))
#             for batch in batches:
#                 texts, annotations = zip(*batch)
#                 nlp.update(
#                     texts,  # batch of texts
#                     annotations,  # batch of annotations
#                     drop=0.5,  # dropout - make it harder to memorise data
#                     losses=losses,
#                 )
#             print("Losses", losses)
#
#     # test the trained model
#     for text, _ in TRAIN_DATA:
#         doc = nlp(text)
#         print("Entities", [(ent.text, ent.label_) for ent in doc.ents])
#         print("Tokens", [(t.text, t.ent_type_, t.ent_iob) for t in doc])
#
#     # save model to output directory
#     if output_dir is not None:
#         output_dir = Path(output_dir)
#         if not output_dir.exists():
#             output_dir.mkdir()
#         nlp.to_disk(output_dir)
#         print("Saved model to", output_dir)
#
#         # test the saved model
#         print("Loading from", output_dir)
#         nlp2 = spacy.load(output_dir)
#         for text, _ in TRAIN_DATA:
#             doc = nlp2(text)
#             print("Entities", [(ent.text, ent.label_) for ent in doc.ents])
#             print("Tokens", [(t.text, t.ent_type_, t.ent_iob) for t in doc])
# ```

# %%
listo = []
for index, item in TRAIN_DATA.iterrows():
    listo.append((item['TEXT'], {"entities": [(item['START'], item['END'], "STREET")]}))
listo
# Out:
# [('1st Street', {'entities': [(0, 10, 'STREET')]}),
#  ('2nd Street', {'entities': [(0, 10, 'STREET')]}),
#  ('3rd Street', {'entities': [(0, 10, 'STREET')]}),
#  ('4th Street', {'entities': [(0, 10, 'STREET')]}),
#  ('5th Street', {'entities': [(0, 10, 'STREET')]}),
#  ('6th Street', {'entities': [(0, 10, 'STREET')]}),
#  ('8th Street', {'entities': [(0, 10, 'STREET')]}),
#  ('9th Street', {'entities': [(0, 10, 'STREET')]}),
#  ('Adams Street', {'entities': [(0, 12, 'STREET')]}),
#  ('Adelphian Way', {'entities': [(0, 13, 'STREET')]}),
#  ('Admiralty Lane', {'entities': [(0, 14, 'STREET')]}),
#  ('Alameda Avenue', {'entities': [(0, 14, 'STREET')]}),
#  ('Alameda Road', {'entities': [(0, 12, 'STREET')]}),
#  ('Alaska Packer Place', {'entities': [(0, 19, 'STREET')]}),
#  ('Alta Vis', {'entities': [(0, 8, 'STREET')]}),
#  ('Amber Isle', {'entities': [(0, 10, 'STREET')]}),
#  ('Anchor Way', {'entities': [(0, 10, 'STREET')]}),
#  ('Anderson Road', {'entities': [(0, 13, 'STREET')]}),
#  ('Annapolis Circle', {'entities': [(0, 16, 'STREET')]}),
#  ('Ansel Avenue', {'entities': [(0, 12, 'STREET')]}),
#  ('Applegate Way', {'entities': [(0, 13, 'STREET')]}),
#  ('Arbor Street', {'entities': [(0, 12, 'STREET')]}),
#  ('Argus Court', {'entities': [(0, 11, 'STREET')]}),
#  ('Arkansas', {'entities': [(0, 8, 'STREET')]}),
#  ('Arlington Isle', {'entities': [(0, 14, 'STREET')]}),
#  ('Armitage Street', {'entities': [(0, 15, 'STREET')]}),
#  ('Asby Bay', {'entities': [(0, 8, 'STREET')]}),
#  ('Atlantic Avenue', {'entities': [(0, 15, 'STREET')]}),
#  ('Auburn Court', {'entities': [(0, 12, 'STREET')]}),
#  ('Auburn Drive', {'entities': [(0, 12, 'STREET')]}),
#  ('Aughinbaugh Way', {'entities': [(0, 15, 'STREET')]}),
#  ('Austin Street', {'entities': [(0, 13, 'STREET')]}),
#  ('Avenue C', {'entities': [(0, 8, 'STREET')]}),
#  ('Avenue D', {'entities': [(0, 8, 'STREET')]}),
#  ('Avenue F', {'entities': [(0, 8, 'STREET')]}),
#  ('Avenue G', {'entities': [(0, 8, 'STREET')]}),
#  ('Avenue H', {'entities': [(0, 8, 'STREET')]}),
#  ('Avenue L', {'entities': [(0, 8, 'STREET')]}),
#  ('Avington Road', {'entities': [(0, 13, 'STREET')]}),
#  ('Avocet Court', {'entities': [(0, 12, 'STREET')]}),
#  ('Avondale Lndg', {'entities': [(0, 13, 'STREET')]}),
#  ('Azalea Drive', {'entities': [(0, 12, 'STREET')]}),
#  ('Bainbridge Court', {'entities': [(0, 16, 'STREET')]}),
#  ('Bainbridge Square', {'entities': [(0, 17, 'STREET')]}),
#  ('Balboa Court', {'entities': [(0, 12, 'STREET')]}),
#  ('Bali Lane', {'entities': [(0, 9, 'STREET')]}),
#  ('Ballena Boulevard', {'entities': [(0, 17, 'STREET')]}),
#  ('Balleybay', {'entities': [(0, 9, 'STREET')]}),
#  ('Bannister Court', {'entities': [(0, 15, 'STREET')]}),
#  ('Bannister Way', {'entities': [(0, 13, 'STREET')]}),
#  ('Barbers Point Road', {'entities': [(0, 18, 'STREET')]}),
#  ('Barker Court', {'entities': [(0, 12, 'STREET')]}),
#  ('Barnegate Bay', {'entities': [(0, 13, 'STREET')]}),
#  ('Barry Court', {'entities': [(0, 11, 'STREET')]}),
#  ('Bartlett Drive', {'entities': [(0, 14, 'STREET')]}),
#  ('Basinside Way', {'entities': [(0, 13, 'STREET')]}),
#  ('Bay Park Terrace', {'entities': [(0, 16, 'STREET')]}),
#  ('Bay Street', {'entities': [(0, 10, 'STREET')]}),
#  ('Bayo Vista Avenue', {'entities': [(0, 17, 'STREET')]}),
#  ('Bayview Drive', {'entities': [(0, 13, 'STREET')]}),
#  ('Baywalk Road', {'entities': [(0, 12, 'STREET')]}),
#  ('Baywood Road', {'entities': [(0, 12, 'STREET')]}),
#  ('Beach Road', {'entities': [(0, 10, 'STREET')]}),
#  ('Beaufort Harbor Lndg', {'entities': [(0, 20, 'STREET')]}),
#  ('Begonia Drive', {'entities': [(0, 13, 'STREET')]}),
#  ('Belmont Place', {'entities': [(0, 13, 'STREET')]}),
#  ('Belmont Way', {'entities': [(0, 11, 'STREET')]}),
#  ('Benedict Court', {'entities': [(0, 14, 'STREET')]}),
#  ('Benton Street', {'entities': [(0, 13, 'STREET')]}),
#  ('Berkshire Road', {'entities': [(0, 14, 'STREET')]}),
#  ('Bertero Court', {'entities': [(0, 13, 'STREET')]}),
#  ('Bertero Square', {'entities': [(0, 14, 'STREET')]}),
#  ('Bird Court', {'entities': [(0, 10, 'STREET')]}),
#  ('Biscay Bay', {'entities': [(0, 10, 'STREET')]}),
#  ('Bishop Street', {'entities': [(0, 13, 'STREET')]}),
#  ('Bismarck Lane', {'entities': [(0, 13, 'STREET')]}),
#  ('Blanding Avenue', {'entities': [(0, 15, 'STREET')]}),
#  ('Bordwell Court', {'entities': [(0, 14, 'STREET')]}),
#  ('Bosshard Court', {'entities': [(0, 14, 'STREET')]}),
#  ('Bowman Court', {'entities': [(0, 12, 'STREET')]}),
#  ('Brehaut Court', {'entities': [(0, 13, 'STREET')]}),
#  ('Bridge View Isle', {'entities': [(0, 16, 'STREET')]}),
#  ('Bridgeview Isle', {'entities': [(0, 15, 'STREET')]}),
#  ('Briggs Avenue', {'entities': [(0, 13, 'STREET')]}),
#  ('Brighton Court', {'entities': [(0, 14, 'STREET')]}),
#  ('Brighton Road', {'entities': [(0, 13, 'STREET')]}),
#  ('Brithorn Lane', {'entities': [(0, 13, 'STREET')]}),
#  ('Britt Court', {'entities': [(0, 11, 'STREET')]}),
#  ('Broadway', {'entities': [(0, 8, 'STREET')]}),
#  ('Brower Court', {'entities': [(0, 12, 'STREET')]}),
#  ('Brown Street', {'entities': [(0, 12, 'STREET')]}),
#  ('Brunswick Road', {'entities': [(0, 14, 'STREET')]}),
#  ('Brush Street', {'entities': [(0, 12, 'STREET')]}),
#  ('Bryant Avenue', {'entities': [(0, 13, 'STREET')]}),
#  ('Buena Vista Avenue', {'entities': [(0, 18, 'STREET')]}),
#  ('Burbank Street', {'entities': [(0, 14, 'STREET')]}),
#  ('Burgner Avenue', {'entities': [(0, 14, 'STREET')]}),
#  ('Calhoun Street', {'entities': [(0, 14, 'STREET')]}),
#  ('California', {'entities': [(0, 10, 'STREET')]}),
#  ('Callan Place', {'entities': [(0, 12, 'STREET')]}),
#  ('Cam del Valle', {'entities': [(0, 13, 'STREET')]}),
#  ('Camanoe Lane', {'entities': [(0, 12, 'STREET')]}),
#  ('Cambridge Drive', {'entities': [(0, 15, 'STREET')]}),
#  ('Camden Road', {'entities': [(0, 11, 'STREET')]}),
#  ('Camellia Drive', {'entities': [(0, 14, 'STREET')]}),
#  ('Campbell Boulevard', {'entities': [(0, 18, 'STREET')]}),
#  ('Campbell Drive', {'entities': [(0, 14, 'STREET')]}),
#  ('Cape Cod Court', {'entities': [(0, 14, 'STREET')]}),
#  ('Capella Lane', {'entities': [(0, 12, 'STREET')]}),
#  ('Capetown Drive', {'entities': [(0, 14, 'STREET')]}),
#  ('Captains Drive', {'entities': [(0, 14, 'STREET')]}),
#  ('Cardigan Bay', {'entities': [(0, 12, 'STREET')]}),
#  ('Carl Vinson', {'entities': [(0, 11, 'STREET')]}),
#  ('Carob Lane', {'entities': [(0, 10, 'STREET')]}),
#  ('Caroline Street', {'entities': [(0, 15, 'STREET')]}),
#  ('Castlebar Place', {'entities': [(0, 15, 'STREET')]}),
#  ('Catalina Avenue', {'entities': [(0, 15, 'STREET')]}),
#  ('Cedar Street', {'entities': [(0, 12, 'STREET')]}),
#  ('Centennial Avenue', {'entities': [(0, 17, 'STREET')]}),
#  ('Central Avenue', {'entities': [(0, 14, 'STREET')]}),
#  ('Centre Court', {'entities': [(0, 12, 'STREET')]}),
#  ('Cerro Vis', {'entities': [(0, 9, 'STREET')]}),
#  ('Cerruti Court', {'entities': [(0, 13, 'STREET')]}),
#  ('Challen Court', {'entities': [(0, 13, 'STREET')]}),
#  ('Challenger Drive', {'entities': [(0, 16, 'STREET')]}),
#  ('Channing Way', {'entities': [(0, 12, 'STREET')]}),
#  ('Chapin Street', {'entities': [(0, 13, 'STREET')]}),
#  ('Chatham Pointe', {'entities': [(0, 14, 'STREET')]}),
#  ('Cheshire Court', {'entities': [(0, 14, 'STREET')]}),
#  ('Chester Street', {'entities': [(0, 14, 'STREET')]}),
#  ('Chestnut Street', {'entities': [(0, 15, 'STREET')]}),
#  ('Cheswick Court', {'entities': [(0, 14, 'STREET')]}),
#  ('Chicago', {'entities': [(0, 7, 'STREET')]}),
#  ('Chilmark Lane', {'entities': [(0, 13, 'STREET')]}),
#  ('Chinaberry Lane', {'entities': [(0, 15, 'STREET')]}),
#  ('Chipman Street', {'entities': [(0, 14, 'STREET')]}),
#  ('Christensen Court', {'entities': [(0, 17, 'STREET')]}),
#  ('Cimarron Street', {'entities': [(0, 15, 'STREET')]}),
#  ('Clarke Lane', {'entities': [(0, 11, 'STREET')]}),
#  ('Clay Street', {'entities': [(0, 11, 'STREET')]}),
#  ('Clement Avenue', {'entities': [(0, 14, 'STREET')]}),
#  ('Cleveland Court', {'entities': [(0, 15, 'STREET')]}),
#  ('Clinton Avenue', {'entities': [(0, 14, 'STREET')]}),
#  ('Clipper Drive', {'entities': [(0, 13, 'STREET')]}),
#  ('Clubhouse Memorial Road', {'entities': [(0, 23, 'STREET')]}),
#  ('Cohen Court', {'entities': [(0, 11, 'STREET')]}),
#  ('Cola Ballena', {'entities': [(0, 12, 'STREET')]}),
#  ('Cole Lane', {'entities': [(0, 9, 'STREET')]}),
#  ('Coleport Lndg', {'entities': [(0, 13, 'STREET')]}),
#  ('College Avenue', {'entities': [(0, 14, 'STREET')]}),
#  ('Concordia Street', {'entities': [(0, 16, 'STREET')]}),
#  ('Constance Circle', {'entities': [(0, 16, 'STREET')]}),
#  ('Cook Lane', {'entities': [(0, 9, 'STREET')]}),
#  ('Coral Reef Place', {'entities': [(0, 16, 'STREET')]}),
#  ('Coral Reef Road', {'entities': [(0, 15, 'STREET')]}),
#  ('Coral Sea Street', {'entities': [(0, 16, 'STREET')]}),
#  ('Cork Road', {'entities': [(0, 9, 'STREET')]}),
#  ('Cormorant Lane', {'entities': [(0, 14, 'STREET')]}),
#  ('Cornelius Square', {'entities': [(0, 16, 'STREET')]}),
#  ('Cornell Drive', {'entities': [(0, 13, 'STREET')]}),
#  ('Corpus Christi Road', {'entities': [(0, 19, 'STREET')]}),
#  ('Costanoan Court', {'entities': [(0, 15, 'STREET')]}),
#  ('Cotella Court', {'entities': [(0, 13, 'STREET')]}),
#  ('Cottage Street', {'entities': [(0, 14, 'STREET')]}),
#  ('Country Isle', {'entities': [(0, 12, 'STREET')]}),
#  ('County Road', {'entities': [(0, 11, 'STREET')]}),
#  ('Court Street', {'entities': [(0, 12, 'STREET')]}),
#  ('Cove Road', {'entities': [(0, 9, 'STREET')]}),
#  ('Crane Court', {'entities': [(0, 11, 'STREET')]}),
#  ('Creedon Circle', {'entities': [(0, 14, 'STREET')]}),
#  ('Crist Street', {'entities': [(0, 12, 'STREET')]}),
#  ('Crolls Garden Court', {'entities': [(0, 19, 'STREET')]}),
#  ('Crown Drive', {'entities': [(0, 11, 'STREET')]}),
#  ('Cumberland Court', {'entities': [(0, 16, 'STREET')]}),
#  ('Cumberland Way', {'entities': [(0, 14, 'STREET')]}),
#  ('Curlew Court', {'entities': [(0, 12, 'STREET')]}),
#  ('Cypress Street', {'entities': [(0, 14, 'STREET')]}),
#  ('Dahlia Drive', {'entities': [(0, 12, 'STREET')]}),
#  ('Damon Court', {'entities': [(0, 11, 'STREET')]}),
#  ('Danbrook Court', {'entities': [(0, 14, 'STREET')]}),
#  ('Dayton Avenue', {'entities': [(0, 13, 'STREET')]}),
#  ('Decelle Court', {'entities': [(0, 13, 'STREET')]}),
#  ('del Mar Avenue', {'entities': [(0, 14, 'STREET')]}),
#  ('Depassier Way', {'entities': [(0, 13, 'STREET')]}),
#  ('Diapian Bay', {'entities': [(0, 11, 'STREET')]}),
#  ('Dolphin Court', {'entities': [(0, 13, 'STREET')]}),
#  ('Doris Court', {'entities': [(0, 11, 'STREET')]}),
#  ('Dow Court', {'entities': [(0, 9, 'STREET')]}),
#  ('Dowitcher Court', {'entities': [(0, 15, 'STREET')]}),
#  ('Dresden Bay', {'entities': [(0, 11, 'STREET')]}),
#  ('Driftwood Lane', {'entities': [(0, 14, 'STREET')]}),
#  ('Drum', {'entities': [(0, 4, 'STREET')]}),
#  ('Duarte Court', {'entities': [(0, 12, 'STREET')]}),
#  ('Dublin Way', {'entities': [(0, 10, 'STREET')]}),
#  ('Dutchcap Lane', {'entities': [(0, 13, 'STREET')]}),
#  ('Dwinelle Court', {'entities': [(0, 14, 'STREET')]}),
#  ('E Shore Drive', {'entities': [(0, 13, 'STREET')]}),
#  ('Eagle Avenue', {'entities': [(0, 12, 'STREET')]}),
#  ('Easter Lane', {'entities': [(0, 11, 'STREET')]}),
#  ('Eastshore Drive', {'entities': [(0, 15, 'STREET')]}),
#  ('Eclipse Court', {'entities': [(0, 13, 'STREET')]}),
#  ('Edison Court', {'entities': [(0, 12, 'STREET')]}),
#  ('Egret Court', {'entities': [(0, 11, 'STREET')]}),
#  ('el Paseo', {'entities': [(0, 8, 'STREET')]}),
#  ('el Portal', {'entities': [(0, 9, 'STREET')]}),
#  ('el Sereno', {'entities': [(0, 9, 'STREET')]}),
#  ('Ellis Court', {'entities': [(0, 11, 'STREET')]}),
#  ('Elm Street', {'entities': [(0, 10, 'STREET')]}),
#  ('Emerson Terrace', {'entities': [(0, 15, 'STREET')]}),
#  ('Encinal Avenue', {'entities': [(0, 14, 'STREET')]}),
#  ('Encounter Bay', {'entities': [(0, 13, 'STREET')]}),
#  ('Ennis Place', {'entities': [(0, 11, 'STREET')]}),
#  ('Ennismore Court', {'entities': [(0, 15, 'STREET')]}),
#  ('Enterprise', {'entities': [(0, 10, 'STREET')]}),
#  ('Esterbrook Court', {'entities': [(0, 16, 'STREET')]}),
#  ('Eugenia Court', {'entities': [(0, 13, 'STREET')]}),
#  ('Evans Court', {'entities': [(0, 11, 'STREET')]}),
#  ('Evelyn Court', {'entities': [(0, 12, 'STREET')]}),
#  ('Everett Street', {'entities': [(0, 14, 'STREET')]}),
#  ('Fair Haven Road', {'entities': [(0, 15, 'STREET')]}),
#  ('Fair Oaks Avenue', {'entities': [(0, 16, 'STREET')]}),
#  ('Fairview Avenue', {'entities': [(0, 15, 'STREET')]}),
#  ('Fairway Place', {'entities': [(0, 13, 'STREET')]}),
#  ('Fallon Lane', {'entities': [(0, 11, 'STREET')]}),
#  ('Fernside Boulevard', {'entities': [(0, 18, 'STREET')]}),
#  ('Ferro Court', {'entities': [(0, 11, 'STREET')]}),
#  ('Ferry Pt', {'entities': [(0, 8, 'STREET')]}),
#  ('Fiji Lane', {'entities': [(0, 9, 'STREET')]}),
#  ('Fillmore Street', {'entities': [(0, 15, 'STREET')]}),
#  ('Fir Avenue', {'entities': [(0, 10, 'STREET')]}),
#  ('Fir Place', {'entities': [(0, 9, 'STREET')]}),
#  ('Fitch Court', {'entities': [(0, 11, 'STREET')]}),
#  ('Fitchburg Avenue', {'entities': [(0, 16, 'STREET')]}),
#  ('Fletcher Court', {'entities': [(0, 14, 'STREET')]}),
#  ('Flint Drive', {'entities': [(0, 11, 'STREET')]}),
#  ('Flora Vis', {'entities': [(0, 9, 'STREET')]}),
#  ('Flower Lane', {'entities': [(0, 11, 'STREET')]}),
#  ('Foley Street', {'entities': [(0, 12, 'STREET')]}),
#  ('Fontana Drive', {'entities': [(0, 13, 'STREET')]}),
#  ('Fortmann Way', {'entities': [(0, 12, 'STREET')]}),
#  ('Fortress Isle', {'entities': [(0, 13, 'STREET')]}),
#  ('Foster Street', {'entities': [(0, 13, 'STREET')]}),
#  ('Fountain Street', {'entities': [(0, 15, 'STREET')]}),
#  ('Franciscan Way', {'entities': [(0, 14, 'STREET')]}),
#  ('Fremont Drive', {'entities': [(0, 13, 'STREET')]}),
#  ('Fulton Lane', {'entities': [(0, 11, 'STREET')]}),
#  ('Fundy Bay', {'entities': [(0, 9, 'STREET')]}),
#  ('Gainsborough Court', {'entities': [(0, 18, 'STREET')]}),
#  ('Galway Bay', {'entities': [(0, 10, 'STREET')]}),
#  ('Garden Road', {'entities': [(0, 11, 'STREET')]}),
#  ('Gardenia Terrace', {'entities': [(0, 16, 'STREET')]}),
#  ('Garfield Avenue', {'entities': [(0, 15, 'STREET')]}),
#  ('Gibbons Drive', {'entities': [(0, 13, 'STREET')]}),
#  ('Gilbert Lane', {'entities': [(0, 12, 'STREET')]}),
#  ('Glenview', {'entities': [(0, 8, 'STREET')]}),
#  ('Glenview Street', {'entities': [(0, 15, 'STREET')]}),
#  ('Glenwood Isle', {'entities': [(0, 13, 'STREET')]}),
#  ('Gompers', {'entities': [(0, 7, 'STREET')]}),
#  ('Gonsalves Court', {'entities': [(0, 15, 'STREET')]}),
#  ('Gould Court', {'entities': [(0, 11, 'STREET')]}),
#  ('Grace Court', {'entities': [(0, 11, 'STREET')]}),
#  ('Grand Street', {'entities': [(0, 12, 'STREET')]}),
#  ('Greenbrier Road', {'entities': [(0, 15, 'STREET')]}),
#  ('Gresham Drive', {'entities': [(0, 13, 'STREET')]}),
#  ('Grove Street', {'entities': [(0, 12, 'STREET')]}),
#  ('Haight Avenue', {'entities': [(0, 13, 'STREET')]}),
#  ('Haile Street', {'entities': [(0, 12, 'STREET')]}),
#  ('Hampton Court', {'entities': [(0, 13, 'STREET')]}),
#  ('Hansen Avenue', {'entities': [(0, 13, 'STREET')]}),
#  ('Harbor Bay Pkwy', {'entities': [(0, 15, 'STREET')]}),
#  ('Harbor Light Road', {'entities': [(0, 17, 'STREET')]}),
#  ('Harbor Road', {'entities': [(0, 11, 'STREET')]}),
#  ('Harvard Drive', {'entities': [(0, 13, 'STREET')]}),
#  ('Hawthorne Street', {'entities': [(0, 16, 'STREET')]}),
#  ('Hays Court', {'entities': [(0, 10, 'STREET')]}),
#  ('Hazel Lane', {'entities': [(0, 10, 'STREET')]}),
#  ('Hecker Court', {'entities': [(0, 12, 'STREET')]}),
#  ('Hercules Court', {'entities': [(0, 14, 'STREET')]}),
#  ('Heron Court', {'entities': [(0, 11, 'STREET')]}),
#  ('Hibbard Street', {'entities': [(0, 14, 'STREET')]}),
#  ('High Street', {'entities': [(0, 11, 'STREET')]}),
#  ('Hillery Way', {'entities': [(0, 11, 'STREET')]}),
#  ('Hollister Avenue', {'entities': [(0, 16, 'STREET')]}),
#  ('Holly Oak Lane', {'entities': [(0, 14, 'STREET')]}),
#  ('Holly Street', {'entities': [(0, 12, 'STREET')]}),
#  ('Holtz Court', {'entities': [(0, 11, 'STREET')]}),
#  ('Hoover Court', {'entities': [(0, 12, 'STREET')]}),
#  ('Hudson Bay', {'entities': [(0, 10, 'STREET')]}),
#  ('Independence Drive', {'entities': [(0, 18, 'STREET')]}),
#  ('Indian Bay', {'entities': [(0, 10, 'STREET')]}),
#  ('Inverness Court', {'entities': [(0, 15, 'STREET')]}),
#  ('Inverness Way', {'entities': [(0, 13, 'STREET')]}),
#  ('Invincible Court', {'entities': [(0, 16, 'STREET')]}),
#  ('Ironwood Road', {'entities': [(0, 13, 'STREET')]}),
#  ('Island Drive', {'entities': [(0, 12, 'STREET')]}),
#  ('Jack London Avenue', {'entities': [(0, 18, 'STREET')]}),
#  ('Jackson Street', {'entities': [(0, 14, 'STREET')]}),
#  ('Janis Circle', {'entities': [(0, 12, 'STREET')]}),
#  ('Jay Street', {'entities': [(0, 10, 'STREET')]}),
#  ('Jervis Bay', {'entities': [(0, 10, 'STREET')]}),
#  ('Johnson Avenue', {'entities': [(0, 14, 'STREET')]}),
#  ('Jost Lane', {'entities': [(0, 9, 'STREET')]}),
#  ('Jouett Square', {'entities': [(0, 13, 'STREET')]}),
#  ('Justin Circle', {'entities': [(0, 13, 'STREET')]}),
#  ('Kansas City', {'entities': [(0, 11, 'STREET')]}),
#  ('Kara Road', {'entities': [(0, 9, 'STREET')]}),
#  ('Keil Bay', {'entities': [(0, 8, 'STREET')]}),
#  ('Kevington Place', {'entities': [(0, 15, 'STREET')]}),
#  ('Kilkenny Court', {'entities': [(0, 14, 'STREET')]}),
#  ('Kilkenny Place', {'entities': [(0, 14, 'STREET')]}),
#  ('Killarney Place', {'entities': [(0, 15, 'STREET')]}),
#  ('Killdeer Court', {'entities': [(0, 14, 'STREET')]}),
#  ('Killybegs Road', {'entities': [(0, 14, 'STREET')]}),
#  ('Kingfisher Avenue', {'entities': [(0, 17, 'STREET')]}),
#  ('Kings Road', {'entities': [(0, 10, 'STREET')]}),
#  ('Kingsbury Court', {'entities': [(0, 15, 'STREET')]}),
#  ('Kingston Lane', {'entities': [(0, 13, 'STREET')]}),
#  ('Kinkaid Court', {'entities': [(0, 13, 'STREET')]}),
#  ('Kinkaid Square', {'entities': [(0, 14, 'STREET')]}),
#  ('Kirk Street', {'entities': [(0, 11, 'STREET')]}),
#  ('Kiska', {'entities': [(0, 5, 'STREET')]}),
#  ('Kitty Hawk Place', {'entities': [(0, 16, 'STREET')]}),
#  ('Kitty Hawk Road', {'entities': [(0, 15, 'STREET')]}),
#  ('Kofman Court', {'entities': [(0, 12, 'STREET')]}),
#  ('Kofman Pkwy', {'entities': [(0, 11, 'STREET')]}),
#  ('Kollmann Circle', {'entities': [(0, 15, 'STREET')]}),
#  ('la Campania', {'entities': [(0, 11, 'STREET')]}),
#  ('la Cresta', {'entities': [(0, 9, 'STREET')]}),
#  ('la Jolla Drive', {'entities': [(0, 14, 'STREET')]}),
#  ('Lafayette Street', {'entities': [(0, 16, 'STREET')]}),
#  ('Lagoria Court', {'entities': [(0, 13, 'STREET')]}),
#  ('Lagorio Court', {'entities': [(0, 13, 'STREET')]}),
#  ('Laguna Vis', {'entities': [(0, 10, 'STREET')]}),
#  ('Lagunaria Lane', {'entities': [(0, 14, 'STREET')]}),
#  ('Lakehurst Circle', {'entities': [(0, 16, 'STREET')]}),
#  ('Larchmont Isle', {'entities': [(0, 14, 'STREET')]}),
#  ('Laurel Street', {'entities': [(0, 13, 'STREET')]}),
#  ('Lavagetto Court', {'entities': [(0, 15, 'STREET')]}),
#  ('Lawrence Road', {'entities': [(0, 13, 'STREET')]}),
#  ('Lea Court', {'entities': [(0, 9, 'STREET')]}),
#  ('Leeward Lane', {'entities': [(0, 12, 'STREET')]}),
#  ('Lemoore Road', {'entities': [(0, 12, 'STREET')]}),
#  ('Leonard Court', {'entities': [(0, 13, 'STREET')]}),
#  ('Lewelling Court', {'entities': [(0, 15, 'STREET')]}),
#  ('Liberty Avenue', {'entities': [(0, 14, 'STREET')]}),
#  ('Lilac Street', {'entities': [(0, 12, 'STREET')]}),
#  ('Limerick Lane', {'entities': [(0, 13, 'STREET')]}),
#  ('Lina Avenue', {'entities': [(0, 11, 'STREET')]}),
#  ('Lincoln Avenue', {'entities': [(0, 14, 'STREET')]}),
#  ('Lincoln Lane', {'entities': [(0, 12, 'STREET')]}),
#  ('Linda Vis', {'entities': [(0, 9, 'STREET')]}),
#  ('Linden Street', {'entities': [(0, 13, 'STREET')]}),
#  ('Madison Street', {'entities': [(0, 14, 'STREET')]}),
#  ('Magnolia Drive', {'entities': [(0, 14, 'STREET')]}),
#  ('Main Street', {'entities': [(0, 11, 'STREET')]}),
#  ('Maitland Drive', {'entities': [(0, 14, 'STREET')]}),
#  ('Mangrove Lane', {'entities': [(0, 13, 'STREET')]}),
#  ('Maple Way', {'entities': [(0, 9, 'STREET')]}),
#  ('Marianas Lane', {'entities': [(0, 13, 'STREET')]}),
#  ('Marina Drive', {'entities': [(0, 12, 'STREET')]}),
#  ('Marina Village Pkwy', {'entities': [(0, 19, 'STREET')]}),
#  ('Mariner Square Drive', {'entities': [(0, 20, 'STREET')]}),
#  ('Mariner Square Lp', {'entities': [(0, 17, 'STREET')]}),
#  ('Marion Court', {'entities': [(0, 12, 'STREET')]}),
#  ('Market Street', {'entities': [(0, 13, 'STREET')]}),
#  ('Mars', {'entities': [(0, 4, 'STREET')]}),
#  ('Marshall Way', {'entities': [(0, 12, 'STREET')]}),
#  ('Marti Rae Court', {'entities': [(0, 15, 'STREET')]}),
#  ('Mastick Court', {'entities': [(0, 13, 'STREET')]}),
#  ('Mayport Circle', {'entities': [(0, 14, 'STREET')]}),
#  ('McDonnel Road', {'entities': [(0, 13, 'STREET')]}),
#  ('McKay Avenue', {'entities': [(0, 12, 'STREET')]}),
#  ('McMurty Court', {'entities': [(0, 13, 'STREET')]}),
#  ('McSherry Lane', {'entities': [(0, 13, 'STREET')]}),
#  ('McSherry Way', {'entities': [(0, 12, 'STREET')]}),
#  ('Mecartney Road', {'entities': [(0, 14, 'STREET')]}),
#  ('Melrose Avenue', {'entities': [(0, 14, 'STREET')]}),
#  ('Meyers Avenue', {'entities': [(0, 13, 'STREET')]}),
#  ('Millington Court', {'entities': [(0, 16, 'STREET')]}),
#  ('Minturn Street', {'entities': [(0, 14, 'STREET')]}),
#  ('Miranda Court', {'entities': [(0, 13, 'STREET')]}),
#  ('Monarch Street', {'entities': [(0, 14, 'STREET')]}),
#  ('Monte Vista Avenue', {'entities': [(0, 18, 'STREET')]}),
#  ('Montego Bay', {'entities': [(0, 11, 'STREET')]}),
#  ('Monterey Circle', {'entities': [(0, 15, 'STREET')]}),
#  ('Moonlight Terrace', {'entities': [(0, 17, 'STREET')]}),
#  ('Moore Court', {'entities': [(0, 11, 'STREET')]}),
#  ('Moreland Drive', {'entities': [(0, 14, 'STREET')]}),
#  ('Morton Street', {'entities': [(0, 13, 'STREET')]}),
#  ('Mosley Avenue', {'entities': [(0, 13, 'STREET')]}),
#  ('Moss Pointe', {'entities': [(0, 11, 'STREET')]}),
#  ('Mound Street', {'entities': [(0, 12, 'STREET')]}),
#  ('Mount Hood', {'entities': [(0, 10, 'STREET')]}),
#  ('Mozart Street', {'entities': [(0, 13, 'STREET')]}),
#  ('Mulberry Street', {'entities': [(0, 15, 'STREET')]}),
#  ('N Loop Road', {'entities': [(0, 11, 'STREET')]}),
#  ('Nakayama Court', {'entities': [(0, 14, 'STREET')]}),
#  ('Nantucket Way', {'entities': [(0, 13, 'STREET')]}),
#  ('Nason Street', {'entities': [(0, 12, 'STREET')]}),
#  ('Nautilus Street', {'entities': [(0, 15, 'STREET')]}),
#  ('Neptune Gardens Avenue', {'entities': [(0, 22, 'STREET')]}),
#  ('Nevada', {'entities': [(0, 6, 'STREET')]}),
#  ('Newport Road', {'entities': [(0, 12, 'STREET')]}),
#  ('Nimitz Drive', {'entities': [(0, 12, 'STREET')]}),
#  ('Noble Avenue', {'entities': [(0, 12, 'STREET')]}),
#  ('Norfolk Road', {'entities': [(0, 12, 'STREET')]}),
#  ('Norman Lane', {'entities': [(0, 11, 'STREET')]}),
#  ('Northwood Drive', {'entities': [(0, 15, 'STREET')]}),
#  ('Norwich Road', {'entities': [(0, 12, 'STREET')]}),
#  ('Nottingham Court', {'entities': [(0, 16, 'STREET')]}),
#  ('Nottingham Drive', {'entities': [(0, 16, 'STREET')]}),
#  ('Oak Park Drive', {'entities': [(0, 14, 'STREET')]}),
#  ('Oak Street', {'entities': [(0, 10, 'STREET')]}),
#  ('Oceana Street', {'entities': [(0, 13, 'STREET')]}),
#  ('Ohio', {'entities': [(0, 4, 'STREET')]}),
#  ('Ohlone Street', {'entities': [(0, 13, 'STREET')]}),
#  ('Old Alameda Pt', {'entities': [(0, 14, 'STREET')]}),
#  ('Oldcastle Lane', {'entities': [(0, 14, 'STREET')]}),
#  ('Oleander Avenue', {'entities': [(0, 15, 'STREET')]}),
#  ('Orion Street', {'entities': [(0, 12, 'STREET')]}),
#  ('Orr Court', {'entities': [(0, 9, 'STREET')]}),
#  ('Orr Road', {'entities': [(0, 8, 'STREET')]}),
#  ('Otis Drive', {'entities': [(0, 10, 'STREET')]}),
#  ('Oyster Pond Road', {'entities': [(0, 16, 'STREET')]}),
#  ('Oyster Shoals', {'entities': [(0, 13, 'STREET')]}),
#  ('Pacific Avenue', {'entities': [(0, 14, 'STREET')]}),
#  ('Pacific Marina', {'entities': [(0, 14, 'STREET')]}),
#  ('Packet Landing Road', {'entities': [(0, 19, 'STREET')]}),
#  ('Page Street', {'entities': [(0, 11, 'STREET')]}),
#  ('Palace Court', {'entities': [(0, 12, 'STREET')]}),
#  ('Palm Beach Lane', {'entities': [(0, 15, 'STREET')]}),
#  ('Palmera Court', {'entities': [(0, 13, 'STREET')]}),
#  ('Pan Am Way', {'entities': [(0, 10, 'STREET')]}),
#  ('Parfait Lane', {'entities': [(0, 12, 'STREET')]}),
#  ('Parish Court', {'entities': [(0, 12, 'STREET')]}),
#  ('Park Avenue', {'entities': [(0, 11, 'STREET')]}),
#  ('Park Avenue E', {'entities': [(0, 13, 'STREET')]}),
#  ('Park Avenue W', {'entities': [(0, 13, 'STREET')]}),
#  ('Park Street', {'entities': [(0, 11, 'STREET')]}),
#  ('Parodi Court', {'entities': [(0, 12, 'STREET')]}),
#  ('Paru Street', {'entities': [(0, 11, 'STREET')]}),
#  ('Payot Court', {'entities': [(0, 11, 'STREET')]}),
#  ('Payot Lane', {'entities': [(0, 10, 'STREET')]}),
#  ('Peach Street', {'entities': [(0, 12, 'STREET')]}),
#  ('Pearl Harbor Road', {'entities': [(0, 17, 'STREET')]}),
#  ('Pearl Street', {'entities': [(0, 12, 'STREET')]}),
#  ('Pease Court', {'entities': [(0, 11, 'STREET')]}),
#  ('Pelican Court', {'entities': [(0, 13, 'STREET')]}),
#  ('Pensacola Lane', {'entities': [(0, 14, 'STREET')]}),
#  ('Pensacola Road', {'entities': [(0, 14, 'STREET')]}),
#  ('Phoenix Lane', {'entities': [(0, 12, 'STREET')]}),
#  ('Pickrell Square', {'entities': [(0, 15, 'STREET')]}),
#  ('Pioneer Court', {'entities': [(0, 13, 'STREET')]}),
#  ('Plover Court', {'entities': [(0, 12, 'STREET')]}),
#  ('Poggi Street', {'entities': [(0, 12, 'STREET')]}),
#  ('Pond Isle', {'entities': [(0, 9, 'STREET')]}),
#  ('Porta Ballena', {'entities': [(0, 13, 'STREET')]}),
#  ('Portola Avenue', {'entities': [(0, 14, 'STREET')]}),
#  ('Post Office Court', {'entities': [(0, 17, 'STREET')]}),
#  ('Post Street', {'entities': [(0, 11, 'STREET')]}),
#  ('Powell Street', {'entities': [(0, 13, 'STREET')]}),
#  ('Powers Court', {'entities': [(0, 12, 'STREET')]}),
#  ('Puddingstone Road', {'entities': [(0, 17, 'STREET')]}),
#  ('Purcell Drive', {'entities': [(0, 13, 'STREET')]}),
#  ('Pyne Lane', {'entities': [(0, 9, 'STREET')]}),
#  ('Pyro', {'entities': [(0, 4, 'STREET')]}),
#  ('Queens Road', {'entities': [(0, 11, 'STREET')]}),
#  ('Rainbow Court', {'entities': [(0, 13, 'STREET')]}),
#  ('Ralph Appezzato Memorial Pkwy', {'entities': [(0, 29, 'STREET')]}),
#  ('Ranger Court', {'entities': [(0, 12, 'STREET')]}),
#  ('Ratto Road', {'entities': [(0, 10, 'STREET')]}),
#  ('Ravens Cove Lane', {'entities': [(0, 16, 'STREET')]}),
#  ('Rd A', {'entities': [(0, 4, 'STREET')]}),
#  ('Redhook Lane', {'entities': [(0, 12, 'STREET')]}),
#  ('Redondo Court', {'entities': [(0, 13, 'STREET')]}),
#  ('Regent Street', {'entities': [(0, 13, 'STREET')]}),
#  ('Regulus Court', {'entities': [(0, 13, 'STREET')]}),
#  ('Remmel Court', {'entities': [(0, 12, 'STREET')]}),
#  ('Riddell Lane', {'entities': [(0, 12, 'STREET')]}),
#  ('Roanoke Drive', {'entities': [(0, 13, 'STREET')]}),
#  ('Roark', {'entities': [(0, 5, 'STREET')]}),
#  ('Robert Louis Stevenson Avenue', {'entities': [(0, 29, 'STREET')]}),
#  ('Rock Isle', {'entities': [(0, 9, 'STREET')]}),
#  ('Roosevelt Drive', {'entities': [(0, 15, 'STREET')]}),
#  ('Rosefield Loop', {'entities': [(0, 14, 'STREET')]}),
#  ('Rosewood Way', {'entities': [(0, 12, 'STREET')]}),
#  ('Ross Road', {'entities': [(0, 9, 'STREET')]}),
#  ('Roth Lane', {'entities': [(0, 9, 'STREET')]}),
#  ('Rowe Court', {'entities': [(0, 10, 'STREET')]}),
#  ('Roxburg Lane', {'entities': [(0, 12, 'STREET')]}),
#  ('Rutland Court', {'entities': [(0, 13, 'STREET')]}),
#  ('S Loop Road', {'entities': [(0, 11, 'STREET')]}),
#  ('S Shore Center W', {'entities': [(0, 16, 'STREET')]}),
#  ('Sable Pointe', {'entities': [(0, 12, 'STREET')]}),
#  ('Sacramento', {'entities': [(0, 10, 'STREET')]}),
#  ('Salmon Road', {'entities': [(0, 11, 'STREET')]}),
#  ('San Antonio Avenue', {'entities': [(0, 18, 'STREET')]}),
#  ('San Diego Road', {'entities': [(0, 14, 'STREET')]}),
#  ('San Jose Avenue', {'entities': [(0, 15, 'STREET')]}),
#  ('San Pedro Road', {'entities': [(0, 14, 'STREET')]}),
#  ('Sand Beach Place', {'entities': [(0, 16, 'STREET')]}),
#  ('Sand Beach Road', {'entities': [(0, 15, 'STREET')]}),
#  ('Sand Harbor', {'entities': [(0, 11, 'STREET')]}),
#  ('Sand Harbor Road', {'entities': [(0, 16, 'STREET')]}),
#  ('Sand Hook Isle', {'entities': [(0, 14, 'STREET')]}),
#  ('Sandalwood Isle', {'entities': [(0, 15, 'STREET')]}),
#  ('Sandcreek Way', {'entities': [(0, 13, 'STREET')]}),
#  ('Sanderling Court', {'entities': [(0, 16, 'STREET')]}),
#  ('Sandpiper Court', {'entities': [(0, 15, 'STREET')]}),
#  ('Sandpiper Place', {'entities': [(0, 15, 'STREET')]}),
#  ('Santa Clara Avenue', {'entities': [(0, 18, 'STREET')]}),
#  ('Santa Cruz Lane', {'entities': [(0, 15, 'STREET')]}),
#  ('Santa Rosa Lane', {'entities': [(0, 15, 'STREET')]}),
#  ('Saratoga Street', {'entities': [(0, 15, 'STREET')]}),
#  ('Sath Court', {'entities': [(0, 10, 'STREET')]}),
#  ('Savana Lane', {'entities': [(0, 11, 'STREET')]}),
#  ('Schiller Street', {'entities': [(0, 15, 'STREET')]}),
#  ('Sea Brg', {'entities': [(0, 7, 'STREET')]}),
#  ('Sea Bridge Court', {'entities': [(0, 16, 'STREET')]}),
#  ('Sea Bridge Way', {'entities': [(0, 14, 'STREET')]}),
#  ('Sea Horse', {'entities': [(0, 9, 'STREET')]}),
#  ('Sea View Pkwy', {'entities': [(0, 13, 'STREET')]}),
#  ('Seaborn Court', {'entities': [(0, 13, 'STREET')]}),
#  ('Seattle Road', {'entities': [(0, 12, 'STREET')]}),
#  ('Seminary Avenue', {'entities': [(0, 15, 'STREET')]}),
#  ('Serenade Place', {'entities': [(0, 14, 'STREET')]}),
#  ('Shamrock Lane', {'entities': [(0, 13, 'STREET')]}),
#  ('Shaner Drive', {'entities': [(0, 12, 'STREET')]}),
#  ('Shannon Circle', {'entities': [(0, 14, 'STREET')]}),
#  ('Shasta', {'entities': [(0, 6, 'STREET')]}),
#  ('Sheffield Road', {'entities': [(0, 14, 'STREET')]}),
#  ('Shell Gate Place', {'entities': [(0, 16, 'STREET')]}),
#  ('Shell Gate Road', {'entities': [(0, 15, 'STREET')]}),
#  ('Shepardson Lane', {'entities': [(0, 15, 'STREET')]}),
#  ('Sherman Street', {'entities': [(0, 14, 'STREET')]}),
#  ('Sherwood Lane', {'entities': [(0, 13, 'STREET')]}),
#  ('Shoreline Drive', {'entities': [(0, 15, 'STREET')]}),
#  ('Shorepoint Court', {'entities': [(0, 16, 'STREET')]}),
#  ('Siegfried Lane', {'entities': [(0, 14, 'STREET')]}),
#  ('Silva Lane', {'entities': [(0, 10, 'STREET')]}),
#  ('Singleton Avenue', {'entities': [(0, 16, 'STREET')]}),
#  ('Smith Court', {'entities': [(0, 11, 'STREET')]}),
#  ('Solomon Lane', {'entities': [(0, 12, 'STREET')]}),
#  ('Southwood Drive', {'entities': [(0, 15, 'STREET')]}),
#  ('Souza Court', {'entities': [(0, 11, 'STREET')]}),
#  ('Spalding Square', {'entities': [(0, 15, 'STREET')]}),
#  ('Spruce Street', {'entities': [(0, 13, 'STREET')]}),
#  ('St Charles Street', {'entities': [(0, 17, 'STREET')]}),
#  ('St Margaret Court', {'entities': [(0, 17, 'STREET')]}),
#  ('Stanbridge Court', {'entities': [(0, 16, 'STREET')]}),
#  ('Stanbridge Lane', {'entities': [(0, 15, 'STREET')]}),
#  ('Stanford Street', {'entities': [(0, 15, 'STREET')]}),
#  ('Stanton Street', {'entities': [(0, 14, 'STREET')]}),
#  ('Stardust Place', {'entities': [(0, 14, 'STREET')]}),
#  ('Stargell', {'entities': [(0, 8, 'STREET')]}),
#  ('State Route 260', {'entities': [(0, 15, 'STREET')]}),
#  ('State Route 61', {'entities': [(0, 14, 'STREET')]}),
#  ('Sterling Avenue', {'entities': [(0, 15, 'STREET')]}),
#  ('Steuben Bay', {'entities': [(0, 11, 'STREET')]}),
#  ('Stewart Court', {'entities': [(0, 13, 'STREET')]}),
#  ('Stone Harbor', {'entities': [(0, 12, 'STREET')]}),
#  ('Stonington Pointe', {'entities': [(0, 17, 'STREET')]}),
#  ('Straub Way', {'entities': [(0, 10, 'STREET')]}),
#  ('Sunny Cove Circle', {'entities': [(0, 17, 'STREET')]}),
#  ('Sunset Road', {'entities': [(0, 11, 'STREET')]}),
#  ('Sweeney Lane', {'entities': [(0, 12, 'STREET')]}),
#  ('Sweet Road', {'entities': [(0, 10, 'STREET')]}),
#  ('Sweet Way', {'entities': [(0, 9, 'STREET')]}),
#  ('Swift Court', {'entities': [(0, 11, 'STREET')]}),
#  ('Tahiti Lane', {'entities': [(0, 11, 'STREET')]}),
#  ('Tarryton Isle', {'entities': [(0, 13, 'STREET')]}),
#  ('Taylor Avenue', {'entities': [(0, 13, 'STREET')]}),
#  ('Teal Lane', {'entities': [(0, 9, 'STREET')]}),
#  ('Tern Lane', {'entities': [(0, 9, 'STREET')]}),
#  ('Texas', {'entities': [(0, 5, 'STREET')]}),
#  ('Thau Way', {'entities': [(0, 8, 'STREET')]}),
#  ('Thompson Avenue', {'entities': [(0, 15, 'STREET')]}),
#  ('Thurles Place', {'entities': [(0, 13, 'STREET')]}),
#  ('Tideway Drive', {'entities': [(0, 13, 'STREET')]}),
#  ('Tilden Way', {'entities': [(0, 10, 'STREET')]}),
#  ('Times Way', {'entities': [(0, 9, 'STREET')]}),
#  ('Tinker Avenue', {'entities': [(0, 13, 'STREET')]}),
#  ('Tipperary Court', {'entities': [(0, 15, 'STREET')]}),
#  ('Tipperary Lane', {'entities': [(0, 14, 'STREET')]}),
#  ('Tobago Lane', {'entities': [(0, 11, 'STREET')]}),
#  ('Todd Street', {'entities': [(0, 11, 'STREET')]}),
#  ('Tonga Lane', {'entities': [(0, 10, 'STREET')]}),
#  ('Toyon Terrace', {'entities': [(0, 13, 'STREET')]}),
#  ('Tralee Lane', {'entities': [(0, 11, 'STREET')]}),
#  ('Tregloan Court', {'entities': [(0, 14, 'STREET')]}),
#  ('Trellis Lane', {'entities': [(0, 12, 'STREET')]}),
#  ('Tripoli', {'entities': [(0, 7, 'STREET')]}),
#  ('Triumph Drive', {'entities': [(0, 13, 'STREET')]}),
#  ('Tucker Avenue', {'entities': [(0, 13, 'STREET')]}),
#  ('Tullamore Place', {'entities': [(0, 15, 'STREET')]}),
#  ('Tynebourne Place', {'entities': [(0, 16, 'STREET')]}),
#  ('Ulster Place', {'entities': [(0, 12, 'STREET')]}),
#  ('Union Street', {'entities': [(0, 12, 'STREET')]}),
#  ('Van Buren Street', {'entities': [(0, 16, 'STREET')]}),
#  ('Verdemar Drive', {'entities': [(0, 14, 'STREET')]}),
#  ('Verdi Street', {'entities': [(0, 12, 'STREET')]}),
#  ('Versailles Avenue', {'entities': [(0, 17, 'STREET')]}),
#  ('Via Alamosa', {'entities': [(0, 11, 'STREET')]}),
#  ('Via Aliso', {'entities': [(0, 9, 'STREET')]}),
#  ('Via Bahia', {'entities': [(0, 9, 'STREET')]}),
#  ('Via Bonita', {'entities': [(0, 10, 'STREET')]}),
#  ('Victoria Bay', {'entities': [(0, 12, 'STREET')]}),
#  ('Viking Street', {'entities': [(0, 13, 'STREET')]}),
#  ('Vista Road', {'entities': [(0, 10, 'STREET')]}),
#  ('Volberg Court', {'entities': [(0, 13, 'STREET')]}),
#  ('W Essex Drive', {'entities': [(0, 13, 'STREET')]}),
#  ('W Hornet Avenue', {'entities': [(0, 15, 'STREET')]}),
#  ('W Mall Square', {'entities': [(0, 13, 'STREET')]}),
#  ('W Midway Avenue', {'entities': [(0, 15, 'STREET')]}),
#  ('W Oriskany Avenue', {'entities': [(0, 17, 'STREET')]}),
#  ('W Ranger Avenue', {'entities': [(0, 15, 'STREET')]}),
#  ('W Seaplane Lagoon', {'entities': [(0, 17, 'STREET')]}),
#  ('W Tower Avenue', {'entities': [(0, 14, 'STREET')]}),
#  ('W Trident Avenue', {'entities': [(0, 16, 'STREET')]}),
#  ('Walnut Street', {'entities': [(0, 13, 'STREET')]}),
#  ('Washington Court', {'entities': [(0, 16, 'STREET')]}),
#  ('Washington Street', {'entities': [(0, 17, 'STREET')]}),
#  ('Washington Way', {'entities': [(0, 14, 'STREET')]}),
#  ('Washoe Court', {'entities': [(0, 12, 'STREET')]}),
#  ('Waterfall Isle', {'entities': [(0, 14, 'STREET')]}),
#  ('Waterford Place', {'entities': [(0, 15, 'STREET')]}),
#  ('Waterton Street', {'entities': [(0, 15, 'STREET')]}),
#  ('Waterview Isle', {'entities': [(0, 14, 'STREET')]}),
#  ('Wayne Court', {'entities': [(0, 11, 'STREET')]}),
#  ('Webb Avenue', {'entities': [(0, 11, 'STREET')]}),
#  ('Weber Street', {'entities': [(0, 12, 'STREET')]}),
#  ('Webster Street', {'entities': [(0, 14, 'STREET')]}),
#  ('Weiss Court', {'entities': [(0, 11, 'STREET')]}),
#  ('Wellfleet Bay', {'entities': [(0, 13, 'STREET')]}),
#  ('Westline Drive', {'entities': [(0, 14, 'STREET')]}),
#  ('Wexford Place', {'entities': [(0, 13, 'STREET')]}),
#  ('Weymouth Court', {'entities': [(0, 14, 'STREET')]}),
#  ('Whimbrel Court', {'entities': [(0, 14, 'STREET')]}),
#  ('Whitehall Place', {'entities': [(0, 15, 'STREET')]}),
#  ('Whitehall Road', {'entities': [(0, 14, 'STREET')]}),
#  ('Wichita', {'entities': [(0, 7, 'STREET')]}),
#  ('Willet Court', {'entities': [(0, 12, 'STREET')]}),
#  ('Willis Lane', {'entities': [(0, 11, 'STREET')]}),
#  ('Willow Street', {'entities': [(0, 13, 'STREET')]}),
#  ('Winant Way', {'entities': [(0, 10, 'STREET')]}),
#  ('Windemere Isle', {'entities': [(0, 14, 'STREET')]}),
#  ('Windsor Drive', {'entities': [(0, 13, 'STREET')]}),
#  ('Windward Lane', {'entities': [(0, 13, 'STREET')]}),
#  ('Wood Street', {'entities': [(0, 11, 'STREET')]}),
#  ('Yale Drive', {'entities': [(0, 10, 'STREET')]}),
#  ('Yorkshire Place', {'entities': [(0, 15, 'STREET')]}),
#  ('Yorkshire Road', {'entities': [(0, 14, 'STREET')]}),
#  ('Yosemite Avenue', {'entities': [(0, 15, 'STREET')]}),
#  ('Young Street', {'entities': [(0, 12, 'STREET')]}),
#  ('Acton Street', {'entities': [(0, 12, 'STREET')]}),
#  ('Adams Street', {'entities': [(0, 12, 'STREET')]}),
#  ('Albany Terrace', {'entities': [(0, 14, 'STREET')]}),
#  ('Albina Avenue', {'entities': [(0, 13, 'STREET')]}),
#  ('Berkeley Park Boulevard', {'entities': [(0, 23, 'STREET')]}),
#  ('Beverly Place', {'entities': [(0, 13, 'STREET')]}),
#  ('Brighton Avenue', {'entities': [(0, 15, 'STREET')]}),
#  ('Buchanan Street', {'entities': [(0, 15, 'STREET')]}),
#  ('Buchanan Street Exd', {'entities': [(0, 19, 'STREET')]}),
#  ('Calhoun Street', {'entities': [(0, 14, 'STREET')]}),
#  ('Carmel Avenue', {'entities': [(0, 13, 'STREET')]}),
#  ('Castro Street', {'entities': [(0, 13, 'STREET')]}),
#  ('Cerrito Street', {'entities': [(0, 14, 'STREET')]}),
#  ('Clay Street', {'entities': [(0, 11, 'STREET')]}),
#  ('Cleveland Avenue', {'entities': [(0, 16, 'STREET')]}),
#  ('Cornell Avenue', {'entities': [(0, 14, 'STREET')]}),
#  ('Curtis Street', {'entities': [(0, 13, 'STREET')]}),
#  ('Dartmouth Street', {'entities': [(0, 16, 'STREET')]}),
#  ('Evelyn Avenue', {'entities': [(0, 13, 'STREET')]}),
#  ('Fillmore Street', {'entities': [(0, 15, 'STREET')]}),
#  ('Francis Street', {'entities': [(0, 14, 'STREET')]}),
#  ('Garfield Avenue', {'entities': [(0, 15, 'STREET')]}),
#  ('Gateview Avenue', {'entities': [(0, 15, 'STREET')]}),
#  ('Gilman Street', {'entities': [(0, 13, 'STREET')]}),
#  ('Gooding Drive', {'entities': [(0, 13, 'STREET')]}),
#  ('Harrison Street', {'entities': [(0, 15, 'STREET')]}),
#  ('Hillside Avenue', {'entities': [(0, 15, 'STREET')]}),
#  ('Hopkins Court', {'entities': [(0, 13, 'STREET')]}),
#  ('Jackson Street', {'entities': [(0, 14, 'STREET')]}),
#  ('Johnson Street', {'entities': [(0, 14, 'STREET')]}),
#  ('Kains Avenue', {'entities': [(0, 12, 'STREET')]}),
#  ('Key Route Boulevard', {'entities': [(0, 19, 'STREET')]}),
#  ('Kinkead Way', {'entities': [(0, 11, 'STREET')]}),
#  ('Kinkhead Way', {'entities': [(0, 12, 'STREET')]}),
#  ('Kula Gulf Way', {'entities': [(0, 13, 'STREET')]}),
#  ('Kwat Gulf Way', {'entities': [(0, 13, 'STREET')]}),
#  ('Liberty Ship Way', {'entities': [(0, 16, 'STREET')]}),
#  ('Madison Street', {'entities': [(0, 14, 'STREET')]}),
#  ('Marin Avenue', {'entities': [(0, 12, 'STREET')]}),
#  ('Masonic Avenue', {'entities': [(0, 14, 'STREET')]}),
#  ('Monroe Street', {'entities': [(0, 13, 'STREET')]}),
#  ('Neilson Street', {'entities': [(0, 14, 'STREET')]}),
#  ('Oak View Avenue', {'entities': [(0, 15, 'STREET')]}),
#  ('Ohlone Avenue', {'entities': [(0, 13, 'STREET')]}),
#  ('Ordway Street', {'entities': [(0, 13, 'STREET')]}),
#  ('Peralta Avenue', {'entities': [(0, 14, 'STREET')]}),
#  ('Pierce Street', {'entities': [(0, 13, 'STREET')]}),
#  ('Polk Street', {'entities': [(0, 11, 'STREET')]}),
#  ('Pomona Avenue', {'entities': [(0, 13, 'STREET')]}),
#  ('Portland Avenue', {'entities': [(0, 15, 'STREET')]}),
#  ('Posen Avenue', {'entities': [(0, 12, 'STREET')]}),
#  ('Ramona Avenue', {'entities': [(0, 13, 'STREET')]}),
#  ('Red Oak Avenue', {'entities': [(0, 14, 'STREET')]}),
#  ('San Carlos Avenue', {'entities': [(0, 17, 'STREET')]}),
#  ('San Gabriel Avenue', {'entities': [(0, 18, 'STREET')]}),
#  ('San Lorenzo Avenue', {'entities': [(0, 18, 'STREET')]}),
#  ('San Pablo Avenue', {'entities': [(0, 16, 'STREET')]}),
#  ('Santa Fe Avenue', {'entities': [(0, 15, 'STREET')]}),
#  ('Solano Avenue', {'entities': [(0, 13, 'STREET')]}),
#  ('Sonoma Avenue', {'entities': [(0, 13, 'STREET')]}),
#  ('Spokane Avenue', {'entities': [(0, 14, 'STREET')]}),
#  ('Stannage Avenue', {'entities': [(0, 15, 'STREET')]}),
#  ('State Route 123', {'entities': [(0, 15, 'STREET')]}),
#  ('Taft Avenue', {'entities': [(0, 11, 'STREET')]}),
#  ('Talbot Avenue', {'entities': [(0, 13, 'STREET')]}),
#  ('Taylor Street', {'entities': [(0, 13, 'STREET')]}),
#  ('Terrace Street', {'entities': [(0, 14, 'STREET')]}),
#  ('Tevlin Street', {'entities': [(0, 13, 'STREET')]}),
#  ('Thousand Oaks Boulevard', {'entities': [(0, 23, 'STREET')]}),
#  ('Ventura Avenue', {'entities': [(0, 14, 'STREET')]}),
#  ('W End Way', {'entities': [(0, 9, 'STREET')]}),
#  ('Washington Avenue', {'entities': [(0, 17, 'STREET')]}),
#  ('Watkins Street', {'entities': [(0, 14, 'STREET')]}),
#  ('West Place', {'entities': [(0, 10, 'STREET')]}),
#  ('10th Street', {'entities': [(0, 11, 'STREET')]}),
#  ('2nd Street', {'entities': [(0, 10, 'STREET')]}),
#  ('3rd Street', {'entities': [(0, 10, 'STREET')]}),
#  ('4th Street', {'entities': [(0, 10, 'STREET')]}),
#  ('5th Street', {'entities': [(0, 10, 'STREET')]}),
#  ('62nd Street', {'entities': [(0, 11, 'STREET')]}),
#  ('63rd Street', {'entities': [(0, 11, 'STREET')]}),
#  ('65th Street', {'entities': [(0, 11, 'STREET')]}),
#  ('66th Street', {'entities': [(0, 11, 'STREET')]}),
#  ('67th Street', {'entities': [(0, 11, 'STREET')]}),
#  ('6th Street', {'entities': [(0, 10, 'STREET')]}),
#  ('7th Street', {'entities': [(0, 10, 'STREET')]}),
#  ('8th Street', {'entities': [(0, 10, 'STREET')]}),
#  ('9th Street', {'entities': [(0, 10, 'STREET')]}),
#  ('Acacia Avenue', {'entities': [(0, 13, 'STREET')]}),
#  ('Acroft Court', {'entities': [(0, 12, 'STREET')]}),
#  ('Acton Circle', {'entities': [(0, 12, 'STREET')]}),
#  ('Acton Cres', {'entities': [(0, 10, 'STREET')]}),
#  ('Acton Street', {'entities': [(0, 12, 'STREET')]}),
#  ('Ada Street', {'entities': [(0, 10, 'STREET')]}),
#  ('Ada Street', {'entities': [(0, 10, 'STREET')]}),
#  ('Addison Street', {'entities': [(0, 14, 'STREET')]}),
#  ('Addison Street', {'entities': [(0, 14, 'STREET')]}),
#  ('Addison Street', {'entities': [(0, 14, 'STREET')]}),
#  ('Addison Street', {'entities': [(0, 14, 'STREET')]}),
#  ('Adeline Street', {'entities': [(0, 14, 'STREET')]}),
#  ('Ajax Place', {'entities': [(0, 10, 'STREET')]}),
#  ('Alamo Avenue', {'entities': [(0, 12, 'STREET')]}),
#  ('Alcatraz', {'entities': [(0, 8, 'STREET')]}),
#  ('Alcatraz', {'entities': [(0, 8, 'STREET')]}),
#  ('Alcatraz', {'entities': [(0, 8, 'STREET')]}),
#  ('Alcatraz Avenue', {'entities': [(0, 15, 'STREET')]}),
#  ('Alcatraz Avenue', {'entities': [(0, 15, 'STREET')]}),
#  ('Alcatraz Avenue', {'entities': [(0, 15, 'STREET')]}),
#  ('Allston Way', {'entities': [(0, 11, 'STREET')]}),
#  ('Allston Way', {'entities': [(0, 11, 'STREET')]}),
#  ('Allston Way', {'entities': [(0, 11, 'STREET')]}),
#  ('Allston Way', {'entities': [(0, 11, 'STREET')]}),
#  ('Alta Road', {'entities': [(0, 9, 'STREET')]}),
#  ('Alvarado Place', {'entities': [(0, 14, 'STREET')]}),
#  ('Alvarado Road', {'entities': [(0, 13, 'STREET')]}),
#  ('Amador Avenue', {'entities': [(0, 13, 'STREET')]}),
#  ('Amherst Avenue', {'entities': [(0, 14, 'STREET')]}),
#  ('Amito Avenue', {'entities': [(0, 12, 'STREET')]}),
#  ('Amito Drive', {'entities': [(0, 11, 'STREET')]}),
#  ('Anson Way', {'entities': [(0, 9, 'STREET')]}),
#  ('Anthony Street', {'entities': [(0, 14, 'STREET')]}),
#  ('Arcade Avenue', {'entities': [(0, 13, 'STREET')]}),
#  ('Arcade Lane', {'entities': [(0, 11, 'STREET')]}),
#  ('Arch Street', {'entities': [(0, 11, 'STREET')]}),
#  ('Arch Street', {'entities': [(0, 11, 'STREET')]}),
#  ('Arden Path', {'entities': [(0, 10, 'STREET')]}),
#  ('Arden Road', {'entities': [(0, 10, 'STREET')]}),
#  ('Arden Steps', {'entities': [(0, 11, 'STREET')]}),
#  ('Ardmore Path', {'entities': [(0, 12, 'STREET')]}),
#  ('Ardmore Road', {'entities': [(0, 12, 'STREET')]}),
#  ('Arlington Avenue', {'entities': [(0, 16, 'STREET')]}),
#  ('Arlington Court', {'entities': [(0, 15, 'STREET')]}),
#  ('Arlington Lane', {'entities': [(0, 14, 'STREET')]}),
#  ('Arlmont Drive', {'entities': [(0, 13, 'STREET')]}),
#  ('Ashby Avenue', {'entities': [(0, 12, 'STREET')]}),
#  ('Ashby Avenue', {'entities': [(0, 12, 'STREET')]}),
#  ('Ashby Avenue', {'entities': [(0, 12, 'STREET')]}),
#  ('Ashby Avenue', {'entities': [(0, 12, 'STREET')]}),
#  ('Ashby Place', {'entities': [(0, 11, 'STREET')]}),
#  ('Atherton Street', {'entities': [(0, 15, 'STREET')]}),
#  ('Atlas Place', {'entities': [(0, 11, 'STREET')]}),
#  ('Avalon Avenue', {'entities': [(0, 13, 'STREET')]}),
#  ('Avalon Walk', {'entities': [(0, 11, 'STREET')]}),
#  ('Avenida Drive', {'entities': [(0, 13, 'STREET')]}),
#  ('Avis Road', {'entities': [(0, 9, 'STREET')]}),
#  ('Avon Road', {'entities': [(0, 9, 'STREET')]}),
#  ('Baker Street', {'entities': [(0, 12, 'STREET')]}),
#  ('Bancroft Steps', {'entities': [(0, 14, 'STREET')]}),
#  ('Bancroft Way', {'entities': [(0, 12, 'STREET')]}),
#  ('Bancroft Way', {'entities': [(0, 12, 'STREET')]}),
#  ('Bancroft Way', {'entities': [(0, 12, 'STREET')]}),
#  ('Bancroft Way', {'entities': [(0, 12, 'STREET')]}),
#  ('Bataan Avenue', {'entities': [(0, 13, 'STREET')]}),
#  ('Bateman Street', {'entities': [(0, 14, 'STREET')]}),
#  ('Bay Area Rapid Transit RR', {'entities': [(0, 25, 'STREET')]}),
#  ('Bay Tree Lane', {'entities': [(0, 13, 'STREET')]}),
#  ('Bay View Place', {'entities': [(0, 14, 'STREET')]}),
#  ('Beloit Avenue', {'entities': [(0, 13, 'STREET')]}),
#  ('Belrose Avenue', {'entities': [(0, 14, 'STREET')]}),
#  ('Belvedere Avenue', {'entities': [(0, 16, 'STREET')]}),
#  ('Benvenue Avenue', {'entities': [(0, 15, 'STREET')]}),
#  ('Benvenue Avenue', {'entities': [(0, 15, 'STREET')]}),
#  ('Berkeley Park Boulevard', {'entities': [(0, 23, 'STREET')]}),
#  ('Berkeley Square', {'entities': [(0, 15, 'STREET')]}),
#  ('Berkeley Way', {'entities': [(0, 12, 'STREET')]}),
#  ('Berkeley Way', {'entities': [(0, 12, 'STREET')]}),
#  ('Berkeley Way', {'entities': [(0, 12, 'STREET')]}),
#  ('Berryman Street', {'entities': [(0, 15, 'STREET')]}),
#  ('Berryman Street', {'entities': [(0, 15, 'STREET')]}),
#  ('Besito Avenue', {'entities': [(0, 13, 'STREET')]}),
#  ('Beverly Court', {'entities': [(0, 13, 'STREET')]}),
#  ('Beverly Place', {'entities': [(0, 13, 'STREET')]}),
#  ('Beverly Road', {'entities': [(0, 12, 'STREET')]}),
#  ('Blake Street', {'entities': [(0, 12, 'STREET')]}),
#  ('Blake Street', {'entities': [(0, 12, 'STREET')]}),
#  ('Blake Street', {'entities': [(0, 12, 'STREET')]}),
#  ('Boise Street', {'entities': [(0, 12, 'STREET')]}),
#  ('Bolivar Drive', {'entities': [(0, 13, 'STREET')]}),
#  ('Bonar Street', {'entities': [(0, 12, 'STREET')]}),
#  ('Bonita Avenue', {'entities': [(0, 13, 'STREET')]}),
#  ('Bonita Avenue', {'entities': [(0, 13, 'STREET')]}),
#  ('Bonnie Lane', {'entities': [(0, 11, 'STREET')]}),
#  ('Bowditch Street', {'entities': [(0, 15, 'STREET')]}),
#  ('Boynton Avenue', {'entities': [(0, 14, 'STREET')]}),
#  ('Boynton Walk', {'entities': [(0, 12, 'STREET')]}),
#  ('Breakwater Drive', {'entities': [(0, 16, 'STREET')]}),
#  ('Bret Harte Road', {'entities': [(0, 15, 'STREET')]}),
#  ('Bret Harte Way', {'entities': [(0, 14, 'STREET')]}),
#  ('Bridge Road', {'entities': [(0, 11, 'STREET')]}),
#  ('Bristol Drive', {'entities': [(0, 13, 'STREET')]}),
#  ('Brookside Avenue', {'entities': [(0, 16, 'STREET')]}),
#  ('Brookside Court', {'entities': [(0, 15, 'STREET')]}),
#  ('Brookside Drive', {'entities': [(0, 15, 'STREET')]}),
#  ('Browning Street', {'entities': [(0, 15, 'STREET')]}),
#  ('Buchanan Street', {'entities': [(0, 15, 'STREET')]}),
#  ('Buckingham Boulevard', {'entities': [(0, 20, 'STREET')]}),
#  ('Buena Avenue', {'entities': [(0, 12, 'STREET')]}),
#  ('Buena Court', {'entities': [(0, 11, 'STREET')]}),
#  ('Buena Vista Way', {'entities': [(0, 15, 'STREET')]}),
#  ('Burnett Street', {'entities': [(0, 14, 'STREET')]}),
#  ('Byron Street', {'entities': [(0, 12, 'STREET')]}),
#  ('California', {'entities': [(0, 10, 'STREET')]}),
#  ('California Street', {'entities': [(0, 17, 'STREET')]}),
#  ('Cambridge Avenue', {'entities': [(0, 16, 'STREET')]}),
#  ('Camelia Street', {'entities': [(0, 14, 'STREET')]}),
#  ('Camelia Street', {'entities': [(0, 14, 'STREET')]}),
#  ('Camelot Court', {'entities': [(0, 13, 'STREET')]}),
#  ('Campus Drive', {'entities': [(0, 12, 'STREET')]}),
#  ('Canon Drive', {'entities': [(0, 11, 'STREET')]}),
#  ('Canyon Road', {'entities': [(0, 11, 'STREET')]}),
#  ('Capistrano Avenue', {'entities': [(0, 17, 'STREET')]}),
#  ('Carleton Street', {'entities': [(0, 15, 'STREET')]}),
#  ('Carleton Street', {'entities': [(0, 15, 'STREET')]}),
#  ('Carleton Street', {'entities': [(0, 15, 'STREET')]}),
#  ('Carleton Street', {'entities': [(0, 15, 'STREET')]}),
#  ('Carlotta Avenue', {'entities': [(0, 15, 'STREET')]}),
#  ('Carlotta Avenue', {'entities': [(0, 15, 'STREET')]}),
#  ('Carrison Street', {'entities': [(0, 15, 'STREET')]}),
#  ('Catalina Avenue', {'entities': [(0, 15, 'STREET')]}),
#  ('Catherine Drive', {'entities': [(0, 15, 'STREET')]}),
#  ('Cedar Street', {'entities': [(0, 12, 'STREET')]}),
#  ('Cedar Street', {'entities': [(0, 12, 'STREET')]}),
#  ('Cedar Street', {'entities': [(0, 12, 'STREET')]}),
#  ('Cedar Street', {'entities': [(0, 12, 'STREET')]}),
#  ('Cedar Street', {'entities': [(0, 12, 'STREET')]}),
#  ('Cedarwood Lane', {'entities': [(0, 14, 'STREET')]}),
#  ('Center Street', {'entities': [(0, 13, 'STREET')]}),
#  ('Chancellor Place', {'entities': [(0, 16, 'STREET')]}),
#  ('Channing Way', {'entities': [(0, 12, 'STREET')]}),
#  ('Channing Way', {'entities': [(0, 12, 'STREET')]}),
#  ('Channing Way', {'entities': [(0, 12, 'STREET')]}),
#  ('Channing Way', {'entities': [(0, 12, 'STREET')]}),
#  ('Charing Cross Road', {'entities': [(0, 18, 'STREET')]}),
#  ('Chaucer Street', {'entities': [(0, 14, 'STREET')]}),
#  ('Cherry Street', {'entities': [(0, 13, 'STREET')]}),
#  ('Chestnut Street', {'entities': [(0, 15, 'STREET')]}),
#  ('Chilton Way', {'entities': [(0, 11, 'STREET')]}),
#  ('Claremont', {'entities': [(0, 9, 'STREET')]}),
#  ('Claremont Avenue', {'entities': [(0, 16, 'STREET')]}),
#  ('Claremont Avenue', {'entities': [(0, 16, 'STREET')]}),
#  ('Claremont Boulevard', {'entities': [(0, 19, 'STREET')]}),
#  ('Claremont Cres', {'entities': [(0, 14, 'STREET')]}),
#  ('Cleveland Avenue', {'entities': [(0, 16, 'STREET')]}),
#  ('Codornices Road', {'entities': [(0, 15, 'STREET')]}),
#  ('Colby Street', {'entities': [(0, 12, 'STREET')]}),
#  ('Colgate Avenue', {'entities': [(0, 14, 'STREET')]}),
#  ('College', {'entities': [(0, 7, 'STREET')]}),
#  ('College Avenue', {'entities': [(0, 14, 'STREET')]}),
#  ('College Avenue', {'entities': [(0, 14, 'STREET')]}),
#  ('Colorado Avenue', {'entities': [(0, 15, 'STREET')]}),
#  ('Columbia Avenue', {'entities': [(0, 15, 'STREET')]}),
#  ('Columbia Circle', {'entities': [(0, 15, 'STREET')]}),
#  ('Colusa Avenue', {'entities': [(0, 13, 'STREET')]}),
#  ('Colusa Avenue', {'entities': [(0, 13, 'STREET')]}),
#  ('Comstock Court', {'entities': [(0, 14, 'STREET')]}),
#  ('Contra Costa Avenue', {'entities': [(0, 19, 'STREET')]}),
#  ('Cornell Avenue', {'entities': [(0, 14, 'STREET')]}),
#  ('Corona Court', {'entities': [(0, 12, 'STREET')]}),
#  ('Coventry Road', {'entities': [(0, 13, 'STREET')]}),
#  ('Cowper Avenue', {'entities': [(0, 13, 'STREET')]}),
#  ('Cowper Street', {'entities': [(0, 13, 'STREET')]}),
#  ('Cragmont Avenue', {'entities': [(0, 15, 'STREET')]}),
#  ('Creston Road', {'entities': [(0, 12, 'STREET')]}),
#  ('Crystal Way', {'entities': [(0, 11, 'STREET')]}),
#  ('Curtis Street', {'entities': [(0, 13, 'STREET')]}),
#  ('Curtis Street', {'entities': [(0, 13, 'STREET')]}),
#  ('Cutter Way', {'entities': [(0, 10, 'STREET')]}),
#  ('Cypress Street', {'entities': [(0, 14, 'STREET')]}),
#  ('Dana Street', {'entities': [(0, 11, 'STREET')]}),
#  ('Dana Street', {'entities': [(0, 11, 'STREET')]}),
#  ('Dartmouth Drive', {'entities': [(0, 15, 'STREET')]}),
#  ('Dawn Street', {'entities': [(0, 11, 'STREET')]}),
#  ('Deakin Street', {'entities': [(0, 13, 'STREET')]}),
#  ('del Mar Avenue', {'entities': [(0, 14, 'STREET')]}),
#  ('del Norte Street', {'entities': [(0, 16, 'STREET')]}),
#  ('Delaware Street', {'entities': [(0, 15, 'STREET')]}),
#  ('Delaware Street', {'entities': [(0, 15, 'STREET')]}),
#  ('Delaware Street', {'entities': [(0, 15, 'STREET')]}),
#  ('Delaware Street', {'entities': [(0, 15, 'STREET')]}),
#  ('Derby Street', {'entities': [(0, 12, 'STREET')]}),
#  ('Derby Street', {'entities': [(0, 12, 'STREET')]}),
#  ('Derby Street', {'entities': [(0, 12, 'STREET')]}),
#  ('Devon Way', {'entities': [(0, 9, 'STREET')]}),
#  ('Dewey Road', {'entities': [(0, 10, 'STREET')]}),
#  ('Dohr Street', {'entities': [(0, 11, 'STREET')]}),
#  ('Domingo Avenue', {'entities': [(0, 14, 'STREET')]}),
#  ('Doris Place', {'entities': [(0, 11, 'STREET')]}),
#  ('Dorothy Place', {'entities': [(0, 13, 'STREET')]}),
#  ('Dowling Place', {'entities': [(0, 13, 'STREET')]}),
#  ('Drury Court', {'entities': [(0, 11, 'STREET')]}),
#  ('Drury Lane', {'entities': [(0, 10, 'STREET')]}),
#  ('Drury Road', {'entities': [(0, 10, 'STREET')]}),
#  ('Durant Avenue', {'entities': [(0, 13, 'STREET')]}),
#  ('Dwight Cres', {'entities': [(0, 11, 'STREET')]}),
#  ('Dwight Place', {'entities': [(0, 12, 'STREET')]}),
#  ('Dwight Way', {'entities': [(0, 10, 'STREET')]}),
#  ('Dwight Way', {'entities': [(0, 10, 'STREET')]}),
#  ('Dwight Way', {'entities': [(0, 10, 'STREET')]}),
#  ('Dwight Way', {'entities': [(0, 10, 'STREET')]}),
#  ('E Parnassus Court', {'entities': [(0, 17, 'STREET')]}),
#  ('Eagle Hill', {'entities': [(0, 10, 'STREET')]}),
#  ('Eastshore Frontage Road', {'entities': [(0, 23, 'STREET')]}),
#  ('Eastshore Highway', {'entities': [(0, 17, 'STREET')]}),
#  ('Edgecroft Road', {'entities': [(0, 14, 'STREET')]}),
#  ('Edith Street', {'entities': [(0, 12, 'STREET')]}),
#  ('Edwards Street', {'entities': [(0, 14, 'STREET')]}),
#  ('Edwin Drive', {'entities': [(0, 11, 'STREET')]}),
#  ('el Camino Real', {'entities': [(0, 14, 'STREET')]}),
#  ('el Dorado Avenue', {'entities': [(0, 16, 'STREET')]}),
#  ('el Portal Court', {'entities': [(0, 15, 'STREET')]}),
#  ('Eldridge Court', {'entities': [(0, 14, 'STREET')]}),
#  ('Ellis Street', {'entities': [(0, 12, 'STREET')]}),
#  ('Ellsworth Street', {'entities': [(0, 16, 'STREET')]}),
#  ('Ellsworth Street', {'entities': [(0, 16, 'STREET')]}),
#  ('Elmwood Avenue', {'entities': [(0, 14, 'STREET')]}),
#  ('Elmwood Court', {'entities': [(0, 13, 'STREET')]}),
#  ('Emerson Street', {'entities': [(0, 14, 'STREET')]}),
#  ('Emerson Street', {'entities': [(0, 14, 'STREET')]}),
#  ('Encina Place', {'entities': [(0, 12, 'STREET')]}),
#  ('Ensenada Avenue', {'entities': [(0, 15, 'STREET')]}),
#  ('Eola Street', {'entities': [(0, 11, 'STREET')]}),
#  ('Essex Street', {'entities': [(0, 12, 'STREET')]}),
#  ('Essex Street', {'entities': [(0, 12, 'STREET')]}),
#  ('Estates Drive', {'entities': [(0, 13, 'STREET')]}),
#  ('Estates Road', {'entities': [(0, 12, 'STREET')]}),
#  ('Etna Street', {'entities': [(0, 11, 'STREET')]}),
#  ('Eton Avenue', {'entities': [(0, 11, 'STREET')]}),
#  ('Eton Court', {'entities': [(0, 10, 'STREET')]}),
#  ('Eucalyptus Path', {'entities': [(0, 15, 'STREET')]}),
#  ('Eucalyptus Road', {'entities': [(0, 15, 'STREET')]}),
#  ('Euclid Avenue', {'entities': [(0, 13, 'STREET')]}),
#  ('Euclid Avenue', {'entities': [(0, 13, 'STREET')]}),
#  ('Eunice Street', {'entities': [(0, 13, 'STREET')]}),
#  ('Eunice Street', {'entities': [(0, 13, 'STREET')]}),
#  ('Eureka Avenue', {'entities': [(0, 13, 'STREET')]}),
#  ('Evelyn Avenue', {'entities': [(0, 13, 'STREET')]}),
#  ('Evergreen Lane', {'entities': [(0, 14, 'STREET')]}),
#  ('Fairlawn Drive', {'entities': [(0, 14, 'STREET')]}),
#  ('Fairview Street', {'entities': [(0, 15, 'STREET')]}),
#  ('Fairview Street', {'entities': [(0, 15, 'STREET')]}),
#  ('Ferguson Court', {'entities': [(0, 14, 'STREET')]}),
#  ('Fernwald Road', {'entities': [(0, 13, 'STREET')]}),
#  ('Florence Street', {'entities': [(0, 15, 'STREET')]}),
#  ('Florida Avenue', {'entities': [(0, 14, 'STREET')]}),
#  ('Florida Walk', {'entities': [(0, 12, 'STREET')]}),
#  ('Folger Avenue', {'entities': [(0, 13, 'STREET')]}),
#  ...]

# %%
TRAIN_DATA = streets[['TEXT', 'ENTITY', 'START','END', 'LABEL']]

# %% [markdown]
# ## Summary
# spaCy has a very nice display feature where you can see the color-coded entities. Again, it is pulling large districts and counties, but is not finding street names. We would like to continue exploring this method, but may need to move on to new methods.
